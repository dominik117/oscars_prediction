# %% [markdown]
# # Oscars.com Scraper and Data Saving: Stage 3
#
# Data Collection, Integration and Preprocessing
#
# Hochschule Luzern, 2024
#
# Master's in Applied Information and Data Science
#
# Dominik Bacher Suarez
#
# The following code cleans the scraped data

# %%
from bs4 import BeautifulSoup
import pandas as pd
import json

pd.set_option('display.max_colwidth', 50)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load Stage 1 data

# %%
# Load stage 1 data
try:
    with open('../Data/Bacher_Dominik_studentA_stage1.json', 'r') as file:
        raw_content = json.load(file)
except FileNotFoundError:
    print("File not found. Please check the file path.")
except json.JSONDecodeError:
    print("File is not a valid JSON.")

# %% [markdown]
# ## Scrape Categories by Year

# %%
# Get all the categories given in the Oscars.
# This is needed for the next stage of the scraping, maiinly for the column names
all_categories = set()
categories_dictionary = dict()

for year, content in raw_content.items():
    # Iterate over the years and get the categories for each year
    soup = BeautifulSoup(content, "html.parser")
    categories = soup.find_all("div", {"class": "field--name-field-award-category-oscars"})
    all_categories.update([category.text.strip() for category in categories])
    # IMPURITY 2: Have to convert the set to a list to be able to save it to a CSV file
    categories_dictionary[year] = list(all_categories)

# IMPURITU 3: The categories are not sorted, so we sort them
all_categories = sorted(all_categories)

# Make dataframe with the columns as the categories, and index as the years
df_categories = pd.DataFrame(columns=all_categories, index=categories_dictionary.keys())
# IMPURITY 4: Many issued with the data types, infering fixes this
df_categories = df_categories.infer_objects(copy=False)
# IMPURITY 5: Fill the NaN values with 0, and convert the data type to integer
df_categories.fillna(int(0), inplace=True)
df_categories = df_categories.astype(int)
# Here we set the values to 1 if the category is present for the year
for year, category in categories_dictionary.items():
    for column in category:
        df_categories.loc[year, column] = 1

# %%
df_categories.sample(5)
# Out:
#       Actor in a Leading Role  Actor in a Supporting Role  \
# 2023                        1                           1
# 2016                        1                           1
# 2010                        1                           1
# 2024                        1                           1
# 2017                        1                           1
#
#       Actress in a Leading Role  Actress in a Supporting Role  \
# 2023                          1                             1
# 2016                          1                             1
# 2010                          1                             1
# 2024                          1                             1
# 2017                          1                             1
#
#       Animated Feature Film  Animated Short Film  Art Direction  Best Picture  \
# 2023                      1                    0              1             1
# 2016                      1                    0              1             1
# 2010                      1                    0              1             1
# 2024                      1                    1              1             1
# 2017                      1                    0              1             1
#
#       Cinematography  Costume Design  Directing  Documentary (Feature)  \
# 2023               1               1          1                      1
# 2016               1               1          1                      1
# 2010               1               1          1                      1
# 2024               1               1          1                      1
# 2017               1               1          1                      1
#
#       Documentary (Short Subject)  Documentary Feature Film  \
# 2023                            1                         1
# 2016                            1                         0
# 2010                            1                         0
# 2024                            1                         1
# 2017                            1                         0
#
#       Documentary Short Film  Film Editing  Foreign Language Film  \
# 2023                       1             1                      1
# 2016                       0             1                      1
# 2010                       0             1                      1
# 2024                       1             1                      1
# 2017                       0             1                      1
#
#       International Feature Film  Irving G. Thalberg Memorial Award  \
# 2023                           1                                  1
# 2016                           0                                  1
# 2010                           0                                  1
# 2024                           1                                  1
# 2017                           0                                  1
#
#       Jean Hersholt Humanitarian Award  Live Action Short Film  Makeup  \
# 2023                                 1                       0       1
# 2016                                 1                       0       1
# 2010                                 1                       0       1
# 2024                                 1                       1       1
# 2017                                 1                       0       1
#
#       Makeup and Hairstyling  Music (Original Score)  Music (Original Song)  \
# 2023                       1                       1                      1
# 2016                       1                       1                      1
# 2010                       0                       1                      1
# 2024                       1                       1                      1
# 2017                       1                       1                      1
#
#       Production Design  Short Film (Animated)  Short Film (Live Action)  \
# 2023                  1                      1                         1
# 2016                  1                      1                         1
# 2010                  0                      1                         1
# 2024                  1                      1                         1
# 2017                  1                      1                         1
#
#       Sound  Sound Editing  Sound Mixing  Visual Effects  \
# 2023      1              1             1               1
# 2016      0              1             1               1
# 2010      0              1             1               1
# 2024      1              1             1               1
# 2017      0              1             1               1
#
#       Writing (Adapted Screenplay)  Writing (Original Screenplay)
# 2023                             1                              1
# 2016                             1                              1
# 2010                             1                              1
# 2024                             1                              1
# 2017                             1                              1

# %% [markdown]
# ## Process Awards Data

# %%
def get_movie_cast_html(award, actor=False):
    """ Get the movie cast for the award and category from the HTML content of oscars.org.

    Args:
        award (BeautifulSoup): The award data from oscars.org.
        actor (bool, optional): Whether to select award for an actor or a movie. Defaults to False.

    Returns:
        dict: The winner and nominees for the award.
    """
    if actor:
        index_cast, index_movie = 0, 1
    else:
        index_cast, index_movie = 1, 0

    # IMPURITY #6: The index of the cast and movie title might be switched depending on the award
    # First get the encasing div of the winner data
    winner_div = award.find('div', string=lambda text: text and 'Winner' in text).find_parent('div')
    # Get the actor and the movie title
    winner_cast = winner_div.find_all("div", {"class": "field__item"})[index_cast].text.strip()
    winner_movie = winner_div.find_all("div", {"class": "field__item"})[index_movie].text.strip()

    # Get the siblings from the winner div, these are the nominees
    nominees_divs = winner_div.find_parent('div').find_next_siblings('div')
    nominees_cast = []
    nominees_movies = []
    # Get the cast and movie title for each nominee
    for nominee in nominees_divs:
        nominees_cast.append(nominee.find_all("div", {"class": "field__item"})[index_cast].text.strip())
        nominees_movies.append(nominee.find_all("div", {"class": "field__item"})[index_movie].text.strip())

    # Save the data
    return {
        "winner_movie": winner_movie,
        "winner_cast": winner_cast,
        "nominees_movies": nominees_movies,
        "nominees_cast": nominees_cast
    }

# %%
# IMPURITY #7: The structure of the page is different for the awards for actors and actresses, so we need to handle them separately
exception_acting = ["actor", "actress", "international feature film"]

# create a dictionary to store all the awards
all_oscars_awards = dict()

for year, content in raw_content.items(): 
    soup = BeautifulSoup(content, "html.parser")
    # First filter the div with the awards
    content = soup.find("div", id="view-by-category-pane")
    # Select all the awards that are direct children of the div.field--name-field-award-categories
    all_awards = content.select("div.field--name-field-award-categories > div.field__item")

    all_awards_dict = dict()
    for award in all_awards:
        # Get the category of the award
        category = award.find("div", {"class": "field--name-field-award-category-oscars"}).text.strip()
        # Skip not wanted awards, since these are not for movie titles
        # Award's are given to single individuals, so we can skip these too
        if category == "Music (Original Song)" or "Award" in category:
            # IMPURITY #8: Music (Original Song) AND Award are not related to movie titles
            continue

        # Scraping categories for Actors and Actresses
        # First scarpe awards for actor and actresses since the structure is different, then the rest
        # IMPURITY 9: The years 2019 and 2018 have a different structure for the foreign language film category
        if any(keyword in category.lower() for keyword in exception_acting) or ("foreign language film" in category.lower() and year in [2018, 2019]):
            all_awards_dict[category] = get_movie_cast_html(award, actor=True)

        # Now the rest of the awards that are not for actors and actresses
        else:
            all_awards_dict[category] = get_movie_cast_html(award, actor=False)
    
    # Save the data for each year
    # IMPURITY 10: convert the year to an integer
    all_oscars_awards[int(year)] = all_awards_dict

# %%
print(f"The variable all_oscars_awards has {len(all_oscars_awards)} elements, and is of type {type(all_oscars_awards)}")
# Out:
# The variable all_oscars_awards has 16 elements, and is of type <class 'dict'>

# %%
# Visalize some random samples of the data
print("Random sample of award for Actor in a Leading Role in 2010:")
print(all_oscars_awards[2010]["Actor in a Leading Role"])

print("\n")

print("Random sample of winner for the award for Best Picture in 2014:")
print(all_oscars_awards[2014]["Best Picture"]["winner_movie"])
# Out:
# Random sample of award for Actor in a Leading Role in 2010:
# {'winner_movie': 'Crazy Heart', 'winner_cast': 'Jeff Bridges', 'nominees_movies': ['Up in the Air', 'A Single Man', 'Invictus', 'The Hurt Locker'], 'nominees_cast': ['George Clooney', 'Colin Firth', 'Morgan Freeman', 'Jeremy Renner']}
#
#
# Random sample of winner for the award for Best Picture in 2014:
# 12 Years a Slave

# %%
all_oscars_awards
# Out:
# {2009: {'Actor in a Leading Role': {'winner_movie': 'Milk',
#    'winner_cast': 'Sean Penn',
#    'nominees_movies': ['The Visitor',
#     'Frost/Nixon',
#     'The Curious Case of Benjamin Button',
#     'The Wrestler'],
#    'nominees_cast': ['Richard Jenkins',
#     'Frank Langella',
#     'Brad Pitt',
#     'Mickey Rourke']},
#   'Actor in a Supporting Role': {'winner_movie': 'The Dark Knight',
#    'winner_cast': 'Heath Ledger',
#    'nominees_movies': ['Milk',
#     'Tropic Thunder',
#     'Doubt',
#     'Revolutionary Road'],
#    'nominees_cast': ['Josh Brolin',
#     'Robert Downey Jr.',
#     'Philip Seymour Hoffman',
#     'Michael Shannon']},
#   'Actress in a Leading Role': {'winner_movie': 'The Reader',
#    'winner_cast': 'Kate Winslet',
#    'nominees_movies': ['Rachel Getting Married',
#     'Changeling',
#     'Frozen River',
#     'Doubt'],
#    'nominees_cast': ['Anne Hathaway',
#     'Angelina Jolie',
#     'Melissa Leo',
#     'Meryl Streep']},
#   'Actress in a Supporting Role': {'winner_movie': 'Vicky Cristina Barcelona',
#    'winner_cast': 'Penélope Cruz',
#    'nominees_movies': ['Doubt',
#     'Doubt',
#     'The Curious Case of Benjamin Button',
#     'The Wrestler'],
#    'nominees_cast': ['Amy Adams',
#     'Viola Davis',
#     'Taraji P. Henson',
#     'Marisa Tomei']},
#   'Animated Feature Film': {'winner_movie': 'WALL-E',
#    'winner_cast': 'Andrew Stanton',
#    'nominees_movies': ['Bolt', 'Kung Fu Panda'],
#    'nominees_cast': ['Chris Williams and Byron Howard',
#     'John Stevenson and Mark Osborne']},
#   'Art Direction': {'winner_movie': 'The Curious Case of Benjamin Button',
#    'winner_cast': 'Art Direction: Donald Graham Burt; Set Decoration: Victor J. Zolfo',
#    'nominees_movies': ['Changeling',
#     'The Dark Knight',
#     'The Duchess',
#     'Revolutionary Road'],
#    'nominees_cast': ['Art Direction: James J. Murakami; Set Decoration: Gary Fettis',
#     'Art Direction: Nathan Crowley; Set Decoration: Peter Lando',
#     'Art Direction: Michael Carlin; Set Decoration: Rebecca Alleway',
#     'Art Direction: Kristi Zea; Set Decoration: Debra Schutt']},
#   'Cinematography': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'Anthony Dod Mantle',
#    'nominees_movies': ['Changeling',
#     'The Curious Case of Benjamin Button',
#     'The Dark Knight',
#     'The Reader'],
#    'nominees_cast': ['Tom Stern',
#     'Claudio Miranda',
#     'Wally Pfister',
#     'Chris Menges and Roger Deakins']},
#   'Costume Design': {'winner_movie': 'The Duchess',
#    'winner_cast': "Michael O'Connor",
#    'nominees_movies': ['Australia',
#     'The Curious Case of Benjamin Button',
#     'Milk',
#     'Revolutionary Road'],
#    'nominees_cast': ['Catherine Martin',
#     'Jacqueline West',
#     'Danny Glicker',
#     'Albert Wolsky']},
#   'Directing': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'Danny Boyle',
#    'nominees_movies': ['The Curious Case of Benjamin Button',
#     'Frost/Nixon',
#     'Milk',
#     'The Reader'],
#    'nominees_cast': ['David Fincher',
#     'Ron Howard',
#     'Gus Van Sant',
#     'Stephen Daldry']},
#   'Documentary (Feature)': {'winner_movie': 'Man on Wire',
#    'winner_cast': 'James Marsh and Simon Chinn',
#    'nominees_movies': ['The Betrayal (Nerakhoon)',
#     'Encounters at the End of the World',
#     'The Garden',
#     'Trouble the Water'],
#    'nominees_cast': ['Ellen Kuras and Thavisouk Phrasavath',
#     'Werner Herzog and Henry Kaiser',
#     'Scott Hamilton Kennedy',
#     'Tia Lessin and Carl Deal']},
#   'Documentary (Short Subject)': {'winner_movie': 'Smile Pinki',
#    'winner_cast': 'Megan Mylan',
#    'nominees_movies': ['The Conscience of Nhem En',
#     'The Final Inch',
#     'The Witness - From the Balcony of Room 306'],
#    'nominees_cast': ['Steven Okazaki',
#     'Irene Taylor Brodsky and Tom Grant',
#     'Adam Pertofsky and Margaret Hyde']},
#   'Film Editing': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'Chris Dickens',
#    'nominees_movies': ['The Curious Case of Benjamin Button',
#     'The Dark Knight',
#     'Frost/Nixon',
#     'Milk'],
#    'nominees_cast': ['Kirk Baxter and Angus Wall',
#     'Lee Smith',
#     'Mike Hill and Dan Hanley',
#     'Elliot Graham']},
#   'Foreign Language Film': {'winner_movie': 'Departures',
#    'winner_cast': 'Japan',
#    'nominees_movies': ['The Baader Meinhof Complex',
#     'The Class',
#     'Revanche',
#     'Waltz with Bashir'],
#    'nominees_cast': ['Germany', 'France', 'Austria', 'Israel']},
#   'Makeup': {'winner_movie': 'The Curious Case of Benjamin Button',
#    'winner_cast': 'Greg Cannom',
#    'nominees_movies': ['The Dark Knight', 'Hellboy II: The Golden Army'],
#    'nominees_cast': ["John Caglione, Jr. and Conor O'Sullivan",
#     'Mike Elizalde and Thom Floutz']},
#   'Music (Original Score)': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'A.R. Rahman',
#    'nominees_movies': ['The Curious Case of Benjamin Button',
#     'Defiance',
#     'Milk',
#     'WALL-E'],
#    'nominees_cast': ['Alexandre Desplat',
#     'James Newton Howard',
#     'Danny Elfman',
#     'Thomas Newman']},
#   'Best Picture': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'Christian Colson, Producer',
#    'nominees_movies': ['The Curious Case of Benjamin Button',
#     'Frost/Nixon',
#     'Milk',
#     'The Reader'],
#    'nominees_cast': ['The Curious Case of Benjamin Button',
#     'Brian Grazer, Ron Howard and Eric Fellner, Producers',
#     'Dan Jinks and Bruce Cohen, Producers',
#     'Anthony Minghella, Sydney Pollack, Donna Gigliotti and Redmond Morris, Producers']},
#   'Short Film (Animated)': {'winner_movie': 'La Maison en Petits Cubes',
#    'winner_cast': 'Kunio Kato',
#    'nominees_movies': ['Lavatory - Lovestory',
#     'Oktapodi',
#     'Presto',
#     'This Way Up'],
#    'nominees_cast': ['Konstantin Bronzit',
#     'Emud Mokhberi and Thierry Marchand',
#     'Doug Sweetland',
#     'Alan Smith and Adam Foulkes']},
#   'Short Film (Live Action)': {'winner_movie': 'Spielzeugland (Toyland)',
#    'winner_cast': 'Jochen Alexander Freydank',
#    'nominees_movies': ['Auf der Strecke (On the Line)',
#     'Manon on the Asphalt',
#     'New Boy',
#     'The Pig'],
#    'nominees_cast': ['Reto Caffi',
#     'Elizabeth Marre and Olivier Pont',
#     'Steph Green and Tamara Anghie',
#     'The Pig']},
#   'Sound Editing': {'winner_movie': 'The Dark Knight',
#    'winner_cast': 'Richard King',
#    'nominees_movies': ['Iron Man', 'Slumdog Millionaire', 'WALL-E', 'Wanted'],
#    'nominees_cast': ['Frank Eulner and Christopher Boyes',
#     'Glenn Freemantle and Tom Sayers',
#     'Ben Burtt and Matthew Wood',
#     'Wylie Stateman']},
#   'Sound Mixing': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'Ian Tapp, Richard Pryke and Resul Pookutty',
#    'nominees_movies': ['The Curious Case of Benjamin Button',
#     'The Dark Knight',
#     'WALL-E',
#     'Wanted'],
#    'nominees_cast': ['David Parker, Michael Semanick, Ren Klyce and Mark Weingarten',
#     'Lora Hirschberg, Gary Rizzo and Ed Novick',
#     'Tom Myers, Michael Semanick and Ben Burtt',
#     'Wanted']},
#   'Visual Effects': {'winner_movie': 'The Curious Case of Benjamin Button',
#    'winner_cast': 'Eric Barba, Steve Preeg, Burt Dalton and Craig Barron',
#    'nominees_movies': ['The Dark Knight', 'Iron Man'],
#    'nominees_cast': ['Nick Davis, Chris Corbould, Tim Webber and Paul Franklin',
#     'John Nelson, Ben Snow, Dan Sudick and Shane Mahan']},
#   'Writing (Adapted Screenplay)': {'winner_movie': 'Slumdog Millionaire',
#    'winner_cast': 'Screenplay by Simon Beaufoy',
#    'nominees_movies': ['The Curious Case of Benjamin Button',
#     'Doubt',
#     'Frost/Nixon',
#     'The Reader'],
#    'nominees_cast': ['Screenplay by Eric Roth; Screen story by Eric Roth and Robin Swicord',
#     'Written by John Patrick Shanley',
#     'Screenplay by Peter Morgan',
#     'Screenplay by David Hare']},
#   'Writing (Original Screenplay)': {'winner_movie': 'Milk',
#    'winner_cast': 'Written by Dustin Lance Black',
#    'nominees_movies': ['Frozen River',
#     'Happy-Go-Lucky',
#     'In Bruges',
#     'WALL-E'],
#    'nominees_cast': ['Written by Courtney Hunt',
#     'Written by Mike Leigh',
#     'Written by Martin McDonagh',
#     'Screenplay by Andrew Stanton, Jim Reardon; Original story by Andrew Stanton, Pete Docter']}},
#  2010: {'Actor in a Leading Role': {'winner_movie': 'Crazy Heart',
#    'winner_cast': 'Jeff Bridges',
#    'nominees_movies': ['Up in the Air',
#     'A Single Man',
#     'Invictus',
#     'The Hurt Locker'],
#    'nominees_cast': ['George Clooney',
#     'Colin Firth',
#     'Morgan Freeman',
#     'Jeremy Renner']},
#   'Actor in a Supporting Role': {'winner_movie': 'Inglourious Basterds',
#    'winner_cast': 'Christoph Waltz',
#    'nominees_movies': ['Invictus',
#     'The Messenger',
#     'The Last Station',
#     'The Lovely Bones'],
#    'nominees_cast': ['Matt Damon',
#     'Woody Harrelson',
#     'Christopher Plummer',
#     'Stanley Tucci']},
#   'Actress in a Leading Role': {'winner_movie': 'The Blind Side',
#    'winner_cast': 'Sandra Bullock',
#    'nominees_movies': ['The Last Station',
#     'An Education',
#     "Precious: Based on the Novel 'Push' by Sapphire",
#     'Julie & Julia'],
#    'nominees_cast': ['Helen Mirren',
#     'Carey Mulligan',
#     'Gabourey Sidibe',
#     'Meryl Streep']},
#   'Actress in a Supporting Role': {'winner_movie': "Precious: Based on the Novel 'Push' by Sapphire",
#    'winner_cast': "Mo'Nique",
#    'nominees_movies': ['Nine',
#     'Up in the Air',
#     'Crazy Heart',
#     'Up in the Air'],
#    'nominees_cast': ['Penélope Cruz',
#     'Vera Farmiga',
#     'Maggie Gyllenhaal',
#     'Anna Kendrick']},
#   'Animated Feature Film': {'winner_movie': 'Up',
#    'winner_cast': 'Pete Docter',
#    'nominees_movies': ['Coraline',
#     'Fantastic Mr. Fox',
#     'The Princess and the Frog',
#     'The Secret of Kells'],
#    'nominees_cast': ['Henry Selick',
#     'Wes Anderson',
#     'John Musker and Ron Clements',
#     'Tomm Moore']},
#   'Art Direction': {'winner_movie': 'Avatar',
#    'winner_cast': 'Production Design: Rick Carter and Robert Stromberg; Set Decoration: Kim Sinclair',
#    'nominees_movies': ['The Imaginarium of Doctor Parnassus',
#     'Nine',
#     'Sherlock Holmes',
#     'The Young Victoria'],
#    'nominees_cast': ['Production Design: Dave Warren and Anastasia Masaro; Set Decoration: Caroline Smith',
#     'Production Design: John Myhre; Set Decoration: Gordon Sim',
#     'Production Design: Sarah Greenwood; Set Decoration: Katie Spencer',
#     'Production Design: Patrice Vermette; Set Decoration: Maggie Gray']},
#   'Cinematography': {'winner_movie': 'Avatar',
#    'winner_cast': 'Mauro Fiore',
#    'nominees_movies': ['Harry Potter and the Half-Blood Prince',
#     'The Hurt Locker',
#     'Inglourious Basterds',
#     'The White Ribbon'],
#    'nominees_cast': ['Bruno Delbonnel',
#     'Barry Ackroyd',
#     'Robert Richardson',
#     'Christian Berger']},
#   'Costume Design': {'winner_movie': 'The Young Victoria',
#    'winner_cast': 'Sandy Powell',
#    'nominees_movies': ['Bright Star',
#     'Coco before Chanel',
#     'The Imaginarium of Doctor Parnassus',
#     'Nine'],
#    'nominees_cast': ['Janet Patterson',
#     'Catherine Leterrier',
#     'Monique Prudhomme',
#     'Colleen Atwood']},
#   'Directing': {'winner_movie': 'The Hurt Locker',
#    'winner_cast': 'Kathryn Bigelow',
#    'nominees_movies': ['Avatar',
#     'Inglourious Basterds',
#     "Precious: Based on the Novel 'Push' by Sapphire",
#     'Up in the Air'],
#    'nominees_cast': ['James Cameron',
#     'Quentin Tarantino',
#     'Lee Daniels',
#     'Jason Reitman']},
#   'Documentary (Feature)': {'winner_movie': 'The Cove',
#    'winner_cast': 'Louie Psihoyos and Fisher Stevens',
#    'nominees_movies': ['Burma VJ',
#     'Food, Inc.',
#     'The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers',
#     'Which Way Home'],
#    'nominees_cast': ['Burma VJ',
#     'Robert Kenner and Elise Pearlstein',
#     'Judith Ehrlich and Rick Goldsmith',
#     'Rebecca Cammisa']},
#   'Documentary (Short Subject)': {'winner_movie': 'Music by Prudence',
#    'winner_cast': 'Roger Ross Williams and Elinor Burkett',
#    'nominees_movies': ["China's Unnatural Disaster: The Tears of Sichuan Province",
#     'The Last Campaign of Governor Booth Gardner',
#     'The Last Truck: Closing of a GM Plant',
#     'Rabbit à la Berlin'],
#    'nominees_cast': ["Jon Alpert and Matthew O'Neill",
#     'Daniel Junge and Henry Ansbacher',
#     'Steven Bognar and Julia Reichert',
#     'Bartek Konopka and Anna Wydra']},
#   'Film Editing': {'winner_movie': 'The Hurt Locker',
#    'winner_cast': 'Bob Murawski and Chris Innis',
#    'nominees_movies': ['Avatar',
#     'District 9',
#     'Inglourious Basterds',
#     "Precious: Based on the Novel 'Push' by Sapphire"],
#    'nominees_cast': ['Stephen Rivkin, John Refoua and James Cameron',
#     'Julian Clarke',
#     'Sally Menke',
#     'Joe Klotz']},
#   'Foreign Language Film': {'winner_movie': 'The Secret in Their Eyes',
#    'winner_cast': 'Argentina',
#    'nominees_movies': ['Ajami',
#     'The Milk of Sorrow',
#     'A Prophet',
#     'The White Ribbon'],
#    'nominees_cast': ['Israel', 'Peru', 'France', 'Germany']},
#   'Makeup': {'winner_movie': 'Star Trek',
#    'winner_cast': 'Barney Burman, Mindy Hall and Joel Harlow',
#    'nominees_movies': ['Il Divo', 'The Young Victoria'],
#    'nominees_cast': ['Aldo Signoretti and Vittorio Sodano',
#     'Jon Henry Gordon and Jenny Shircore']},
#   'Music (Original Score)': {'winner_movie': 'Up',
#    'winner_cast': 'Michael Giacchino',
#    'nominees_movies': ['Avatar',
#     'Fantastic Mr. Fox',
#     'The Hurt Locker',
#     'Sherlock Holmes'],
#    'nominees_cast': ['James Horner',
#     'Alexandre Desplat',
#     'Marco Beltrami and Buck Sanders',
#     'Hans Zimmer']},
#   'Best Picture': {'winner_movie': 'The Hurt Locker',
#    'winner_cast': 'Kathryn Bigelow, Mark Boal, Nicolas Chartier and Greg Shapiro, Producers',
#    'nominees_movies': ['Avatar',
#     'The Blind Side',
#     'District 9',
#     'An Education',
#     'Inglourious Basterds',
#     "Precious: Based on the Novel 'Push' by Sapphire",
#     'A Serious Man',
#     'Up',
#     'Up in the Air'],
#    'nominees_cast': ['James Cameron and Jon Landau, Producers',
#     'Gil Netter, Andrew A. Kosove and Broderick Johnson, Producers',
#     'Peter Jackson and Carolynne Cunningham, Producers',
#     'Finola Dwyer and Amanda Posey, Producers',
#     'Lawrence Bender, Producer',
#     'Lee Daniels, Sarah Siegel-Magness and Gary Magness, Producers',
#     'Joel Coen and Ethan Coen, Producers',
#     'Jonas Rivera, Producer',
#     'Daniel Dubiecki, Ivan Reitman and Jason Reitman, Producers']},
#   'Short Film (Animated)': {'winner_movie': 'Logorama',
#    'winner_cast': 'Nicolas Schmerkin',
#    'nominees_movies': ['French Roast',
#     "Granny O'Grimm's Sleeping Beauty",
#     'The Lady and the Reaper (La Dama y la Muerte)',
#     'A Matter of Loaf and Death'],
#    'nominees_cast': ['Fabrice O. Joubert',
#     "Nicky Phelan and Darragh O'Connell",
#     'Javier Recio Gracia',
#     'Nick Park']},
#   'Short Film (Live Action)': {'winner_movie': 'The New Tenants',
#    'winner_cast': 'Joachim Back and Tivi Magnusson',
#    'nominees_movies': ['The Door',
#     'Instead of Abracadabra',
#     'Kavi',
#     'Miracle Fish'],
#    'nominees_cast': ['Juanita Wilson and James Flynn',
#     'Patrik Eklund and Mathias Fjellström',
#     'Gregg Helvey',
#     'Luke Doolan and Drew Bailey']},
#   'Sound Editing': {'winner_movie': 'The Hurt Locker',
#    'winner_cast': 'Paul N.J. Ottosson',
#    'nominees_movies': ['Avatar', 'Inglourious Basterds', 'Star Trek', 'Up'],
#    'nominees_cast': ['Christopher Boyes and Gwendolyn Yates Whittle',
#     'Wylie Stateman',
#     'Mark Stoeckinger and Alan Rankin',
#     'Michael Silvers and Tom Myers']},
#   'Sound Mixing': {'winner_movie': 'The Hurt Locker',
#    'winner_cast': 'Paul N.J. Ottosson and Ray Beckett',
#    'nominees_movies': ['Avatar',
#     'Inglourious Basterds',
#     'Star Trek',
#     'Transformers: Revenge of the Fallen'],
#    'nominees_cast': ['Christopher Boyes, Gary Summers, Andy Nelson and Tony Johnson',
#     'Michael Minkler, Tony Lamberti and Mark Ulano',
#     'Anna Behlmer, Andy Nelson and Peter J. Devlin',
#     'Greg P. Russell, Gary Summers and Geoffrey Patterson']},
#   'Visual Effects': {'winner_movie': 'Avatar',
#    'winner_cast': 'Joe Letteri, Stephen Rosenbaum, Richard Baneham and Andrew R. Jones',
#    'nominees_movies': ['District 9', 'Star Trek'],
#    'nominees_cast': ['Dan Kaufman, Peter Muyzers, Robert Habros and Matt Aitken',
#     'Roger Guyett, Russell Earl, Paul Kavanagh and Burt Dalton']},
#   'Writing (Adapted Screenplay)': {'winner_movie': "Precious: Based on the Novel 'Push' by Sapphire",
#    'winner_cast': 'Screenplay by Geoffrey Fletcher',
#    'nominees_movies': ['District 9',
#     'An Education',
#     'In the Loop',
#     'Up in the Air'],
#    'nominees_cast': ['Written by Neill Blomkamp and Terri Tatchell',
#     'Screenplay by Nick Hornby',
#     'Screenplay by Jesse Armstrong, Simon Blackwell, Armando Iannucci, Tony Roche',
#     'Screenplay by Jason Reitman and Sheldon Turner']},
#   'Writing (Original Screenplay)': {'winner_movie': 'The Hurt Locker',
#    'winner_cast': 'Written by Mark Boal',
#    'nominees_movies': ['Inglourious Basterds',
#     'The Messenger',
#     'A Serious Man',
#     'Up'],
#    'nominees_cast': ['Written by Quentin Tarantino',
#     'Written by Alessandro Camon & Oren Moverman',
#     'Written by Joel Coen & Ethan Coen',
#     'Screenplay by Bob Peterson, Pete Docter; Story by Pete Docter, Bob Peterson, Tom McCarthy']}},
#  2011: {'Actor in a Leading Role': {'winner_movie': "The King's Speech",
#    'winner_cast': 'Colin Firth',
#    'nominees_movies': ['Biutiful',
#     'True Grit',
#     'The Social Network',
#     '127 Hours'],
#    'nominees_cast': ['Javier Bardem',
#     'Jeff Bridges',
#     'Jesse Eisenberg',
#     'James Franco']},
#   'Actor in a Supporting Role': {'winner_movie': 'The Fighter',
#    'winner_cast': 'Christian Bale',
#    'nominees_movies': ["Winter's Bone",
#     'The Town',
#     'The Kids Are All Right',
#     "The King's Speech"],
#    'nominees_cast': ['John Hawkes',
#     'Jeremy Renner',
#     'Mark Ruffalo',
#     'Geoffrey Rush']},
#   'Actress in a Leading Role': {'winner_movie': 'Black Swan',
#    'winner_cast': 'Natalie Portman',
#    'nominees_movies': ['The Kids Are All Right',
#     'Rabbit Hole',
#     "Winter's Bone",
#     'Blue Valentine'],
#    'nominees_cast': ['Annette Bening',
#     'Nicole Kidman',
#     'Jennifer Lawrence',
#     'Michelle Williams']},
#   'Actress in a Supporting Role': {'winner_movie': 'The Fighter',
#    'winner_cast': 'Melissa Leo',
#    'nominees_movies': ['The Fighter',
#     "The King's Speech",
#     'True Grit',
#     'Animal Kingdom'],
#    'nominees_cast': ['Amy Adams',
#     'Helena Bonham Carter',
#     'Hailee Steinfeld',
#     'Jacki Weaver']},
#   'Animated Feature Film': {'winner_movie': 'Toy Story 3',
#    'winner_cast': 'Lee Unkrich',
#    'nominees_movies': ['How to Train Your Dragon', 'The Illusionist'],
#    'nominees_cast': ['Chris Sanders and Dean DeBlois', 'Sylvain Chomet']},
#   'Art Direction': {'winner_movie': 'Alice in Wonderland',
#    'winner_cast': "Production Design: Robert Stromberg; Set Decoration: Karen O'Hara",
#    'nominees_movies': ['Harry Potter and the Deathly Hallows Part 1',
#     'Inception',
#     "The King's Speech",
#     'True Grit'],
#    'nominees_cast': ['Production Design: Stuart Craig; Set Decoration: Stephenie McMillan',
#     'Production Design: Guy Hendrix Dyas; Set Decoration: Larry Dias and Doug Mowat',
#     'Production Design: Eve Stewart; Set Decoration: Judy Farr',
#     'Production Design: Jess Gonchor; Set Decoration: Nancy Haigh']},
#   'Cinematography': {'winner_movie': 'Inception',
#    'winner_cast': 'Wally Pfister',
#    'nominees_movies': ['Black Swan',
#     "The King's Speech",
#     'The Social Network',
#     'True Grit'],
#    'nominees_cast': ['Matthew Libatique',
#     'Danny Cohen',
#     'Jeff Cronenweth',
#     'Roger Deakins']},
#   'Costume Design': {'winner_movie': 'Alice in Wonderland',
#    'winner_cast': 'Colleen Atwood',
#    'nominees_movies': ['I Am Love',
#     "The King's Speech",
#     'The Tempest',
#     'True Grit'],
#    'nominees_cast': ['Antonella Cannarozzi',
#     'Jenny Beavan',
#     'Sandy Powell',
#     'Mary Zophres']},
#   'Directing': {'winner_movie': "The King's Speech",
#    'winner_cast': 'Tom Hooper',
#    'nominees_movies': ['Black Swan',
#     'The Fighter',
#     'The Social Network',
#     'True Grit'],
#    'nominees_cast': ['Darren Aronofsky',
#     'David O. Russell',
#     'David Fincher',
#     'Joel Coen and Ethan Coen']},
#   'Documentary (Feature)': {'winner_movie': 'Inside Job',
#    'winner_cast': 'Charles Ferguson and Audrey Marrs',
#    'nominees_movies': ['Exit through the Gift Shop',
#     'Gasland',
#     'Restrepo',
#     'Waste Land'],
#    'nominees_cast': ["Banksy and Jaimie D'Cruz",
#     'Josh Fox and Trish Adlesic',
#     'Tim Hetherington and Sebastian Junger',
#     'Lucy Walker and Angus Aynsley']},
#   'Documentary (Short Subject)': {'winner_movie': 'Strangers No More',
#    'winner_cast': 'Karen Goodman and Kirk Simon',
#    'nominees_movies': ['Killing in the Name',
#     'Poster Girl',
#     'Sun Come Up',
#     'The Warriors of Qiugang'],
#    'nominees_cast': ['Jed Rothstein',
#     'Sara Nesson and Mitchell W. Block',
#     'Jennifer Redfearn and Tim Metzger',
#     'Ruby Yang and Thomas Lennon']},
#   'Film Editing': {'winner_movie': 'The Social Network',
#    'winner_cast': 'Angus Wall and Kirk Baxter',
#    'nominees_movies': ['Black Swan',
#     'The Fighter',
#     "The King's Speech",
#     '127 Hours'],
#    'nominees_cast': ['Andrew Weisblum',
#     'Pamela Martin',
#     'Tariq Anwar',
#     'Jon Harris']},
#   'Foreign Language Film': {'winner_movie': 'In a Better World',
#    'winner_cast': 'Denmark',
#    'nominees_movies': ['Biutiful',
#     'Dogtooth',
#     'Incendies',
#     'Outside the Law (Hors-la-loi)'],
#    'nominees_cast': ['Mexico', 'Greece', 'Canada', 'Algeria']},
#   'Makeup': {'winner_movie': 'The Wolfman',
#    'winner_cast': 'Rick Baker and Dave Elsey',
#    'nominees_movies': ["Barney's Version", 'The Way Back'],
#    'nominees_cast': ['Adrien Morot',
#     'Edouard F. Henriques, Gregory Funk and Yolanda Toussieng']},
#   'Music (Original Score)': {'winner_movie': 'The Social Network',
#    'winner_cast': 'Trent Reznor and Atticus Ross',
#    'nominees_movies': ['How to Train Your Dragon',
#     'Inception',
#     "The King's Speech",
#     '127 Hours'],
#    'nominees_cast': ['John Powell',
#     'Hans Zimmer',
#     'Alexandre Desplat',
#     'A.R. Rahman']},
#   'Best Picture': {'winner_movie': "The King's Speech",
#    'winner_cast': 'Iain Canning, Emile Sherman and Gareth Unwin, Producers',
#    'nominees_movies': ['Black Swan',
#     'The Fighter',
#     'Inception',
#     'The Kids Are All Right',
#     '127 Hours',
#     'The Social Network',
#     'Toy Story 3',
#     'True Grit',
#     "Winter's Bone"],
#    'nominees_cast': ['Mike Medavoy, Brian Oliver and Scott Franklin, Producers',
#     'David Hoberman, Todd Lieberman and Mark Wahlberg, Producers',
#     'Emma Thomas and Christopher Nolan, Producers',
#     'Gary Gilbert, Jeffrey Levy-Hinte and Celine Rattray, Producers',
#     'Christian Colson, Danny Boyle and John Smithson, Producers',
#     'The Social Network',
#     'Darla K. Anderson, Producer',
#     'Scott Rudin, Ethan Coen and Joel Coen, Producers',
#     'Anne Rosellini and Alix Madigan-Yorkin, Producers']},
#   'Short Film (Animated)': {'winner_movie': 'The Lost Thing',
#    'winner_cast': 'Shaun Tan and Andrew Ruhemann',
#    'nominees_movies': ['Day & Night',
#     'The Gruffalo',
#     "Let's Pollute",
#     'Madagascar, carnet de voyage (Madagascar, a Journey Diary)'],
#    'nominees_cast': ['Teddy Newton',
#     'Jakob Schuh and Max Lang',
#     'Geefwee Boedoe',
#     'Bastien Dubois']},
#   'Short Film (Live Action)': {'winner_movie': 'God of Love',
#    'winner_cast': 'Luke Matheny',
#    'nominees_movies': ['The Confession', 'The Crush', 'Na Wewe', 'Wish 143'],
#    'nominees_cast': ['Tanel Toom',
#     'Michael Creagh',
#     'Ivan Goldschmidt',
#     'Ian Barnes and Samantha Waite']},
#   'Sound Editing': {'winner_movie': 'Inception',
#    'winner_cast': 'Richard King',
#    'nominees_movies': ['Toy Story 3',
#     'Tron: Legacy',
#     'True Grit',
#     'Unstoppable'],
#    'nominees_cast': ['Tom Myers and Michael Silvers',
#     'Gwendolyn Yates Whittle and Addison Teague',
#     'Skip Lievsay and Craig Berkey',
#     'Mark P. Stoeckinger']},
#   'Sound Mixing': {'winner_movie': 'Inception',
#    'winner_cast': 'Lora Hirschberg, Gary A. Rizzo and Ed Novick',
#    'nominees_movies': ["The King's Speech",
#     'Salt',
#     'The Social Network',
#     'True Grit'],
#    'nominees_cast': ['Paul Hamblin, Martin Jensen and John Midgley',
#     'Jeffrey J. Haboush, Greg P. Russell, Scott Millan and William Sarokin',
#     'Ren Klyce, David Parker, Michael Semanick and Mark Weingarten',
#     'Skip Lievsay, Craig Berkey, Greg Orloff and Peter F. Kurland']},
#   'Visual Effects': {'winner_movie': 'Inception',
#    'winner_cast': 'Paul Franklin, Chris Corbould, Andrew Lockley and Peter Bebb',
#    'nominees_movies': ['Alice in Wonderland',
#     'Harry Potter and the Deathly Hallows Part 1',
#     'Hereafter',
#     'Iron Man 2'],
#    'nominees_cast': ['Ken Ralston, David Schaub, Carey Villegas and Sean Phillips',
#     'Tim Burke, John Richardson, Christian Manz and Nicolas Aithadi',
#     'Michael Owens, Bryan Grill, Stephan Trojansky and Joe Farrell',
#     'Janek Sirrs, Ben Snow, Ged Wright and Daniel Sudick']},
#   'Writing (Adapted Screenplay)': {'winner_movie': 'The Social Network',
#    'winner_cast': 'Screenplay by Aaron Sorkin',
#    'nominees_movies': ['127 Hours',
#     'Toy Story 3',
#     'True Grit',
#     "Winter's Bone"],
#    'nominees_cast': ['Screenplay by Danny Boyle & Simon Beaufoy',
#     'Screenplay by Michael Arndt; Story by John Lasseter, Andrew Stanton and Lee Unkrich',
#     'Written for the screen by Joel Coen & Ethan Coen',
#     'Adapted for the screen by Debra Granik & Anne Rosellini']},
#   'Writing (Original Screenplay)': {'winner_movie': "The King's Speech",
#    'winner_cast': 'Screenplay by David Seidler',
#    'nominees_movies': ['Another Year',
#     'The Fighter',
#     'Inception',
#     'The Kids Are All Right'],
#    'nominees_cast': ['Written by Mike Leigh',
#     'Screenplay by Scott Silver and Paul Tamasy & Eric Johnson; Story by Keith Dorrington & Paul Tamasy & Eric Johnson',
#     'Written by Christopher Nolan',
#     'Written by Lisa Cholodenko & Stuart Blumberg']}},
#  2012: {'Actor in a Leading Role': {'winner_movie': 'The Artist',
#    'winner_cast': 'Jean Dujardin',
#    'nominees_movies': ['A Better Life',
#     'The Descendants',
#     'Tinker Tailor Soldier Spy',
#     'Moneyball'],
#    'nominees_cast': ['Demián Bichir',
#     'George Clooney',
#     'Gary Oldman',
#     'Brad Pitt']},
#   'Actor in a Supporting Role': {'winner_movie': 'Beginners',
#    'winner_cast': 'Christopher Plummer',
#    'nominees_movies': ['My Week with Marilyn',
#     'Moneyball',
#     'Warrior',
#     'Extremely Loud & Incredibly Close'],
#    'nominees_cast': ['Kenneth Branagh',
#     'Jonah Hill',
#     'Nick Nolte',
#     'Max von Sydow']},
#   'Actress in a Leading Role': {'winner_movie': 'The Iron Lady',
#    'winner_cast': 'Meryl Streep',
#    'nominees_movies': ['Albert Nobbs',
#     'The Help',
#     'The Girl with the Dragon Tattoo',
#     'My Week with Marilyn'],
#    'nominees_cast': ['Glenn Close',
#     'Viola Davis',
#     'Rooney Mara',
#     'Michelle Williams']},
#   'Actress in a Supporting Role': {'winner_movie': 'The Help',
#    'winner_cast': 'Octavia Spencer',
#    'nominees_movies': ['The Artist',
#     'The Help',
#     'Bridesmaids',
#     'Albert Nobbs'],
#    'nominees_cast': ['Bérénice Bejo',
#     'Jessica Chastain',
#     'Melissa McCarthy',
#     'Janet McTeer']},
#   'Animated Feature Film': {'winner_movie': 'Rango',
#    'winner_cast': 'Gore Verbinski',
#    'nominees_movies': ['A Cat in Paris',
#     'Chico & Rita',
#     'Kung Fu Panda 2',
#     'Puss in Boots'],
#    'nominees_cast': ['Alain Gagnol and Jean-Loup Felicioli',
#     'Fernando Trueba and Javier Mariscal',
#     'Jennifer Yuh Nelson',
#     'Chris Miller']},
#   'Art Direction': {'winner_movie': 'Hugo',
#    'winner_cast': 'Production Design: Dante Ferretti; Set Decoration: Francesca Lo Schiavo',
#    'nominees_movies': ['The Artist',
#     'Harry Potter and the Deathly Hallows Part 2',
#     'Midnight in Paris',
#     'War Horse'],
#    'nominees_cast': ['Production Design: Laurence Bennett; Set Decoration: Robert Gould',
#     'Production Design: Stuart Craig; Set Decoration: Stephenie McMillan',
#     'Production Design: Anne Seibel; Set Decoration: Hélène Dubreuil',
#     'Production Design: Rick Carter; Set Decoration: Lee Sandales']},
#   'Cinematography': {'winner_movie': 'Hugo',
#    'winner_cast': 'Robert Richardson',
#    'nominees_movies': ['The Artist',
#     'The Girl with the Dragon Tattoo',
#     'The Tree of Life',
#     'War Horse'],
#    'nominees_cast': ['Guillaume Schiffman',
#     'Jeff Cronenweth',
#     'Emmanuel Lubezki',
#     'Janusz Kaminski']},
#   'Costume Design': {'winner_movie': 'The Artist',
#    'winner_cast': 'Mark Bridges',
#    'nominees_movies': ['Anonymous', 'Hugo', 'Jane Eyre', 'W.E.'],
#    'nominees_cast': ['Lisy Christl',
#     'Sandy Powell',
#     "Michael O'Connor",
#     'Arianne Phillips']},
#   'Directing': {'winner_movie': 'The Artist',
#    'winner_cast': 'Michel Hazanavicius',
#    'nominees_movies': ['The Descendants',
#     'Hugo',
#     'Midnight in Paris',
#     'The Tree of Life'],
#    'nominees_cast': ['Alexander Payne',
#     'Martin Scorsese',
#     'Woody Allen',
#     'Terrence Malick']},
#   'Documentary (Feature)': {'winner_movie': 'Undefeated',
#    'winner_cast': 'TJ Martin, Dan Lindsay and Rich Middlemas',
#    'nominees_movies': ['Hell and Back Again',
#     'If a Tree Falls: A Story of the Earth Liberation Front',
#     'Paradise Lost 3: Purgatory',
#     'Pina'],
#    'nominees_cast': ['Danfung Dennis and Mike Lerner',
#     'Marshall Curry and Sam Cullman',
#     'Joe Berlinger and Bruce Sinofsky',
#     'Wim Wenders and Gian-Piero Ringel']},
#   'Documentary (Short Subject)': {'winner_movie': 'Saving Face',
#    'winner_cast': 'Daniel Junge and Sharmeen Obaid-Chinoy',
#    'nominees_movies': ['The Barber of Birmingham: Foot Soldier of the Civil Rights Movement',
#     'God Is the Bigger Elvis',
#     'Incident in New Baghdad',
#     'The Tsunami and the Cherry Blossom'],
#    'nominees_cast': ['Robin Fryday and Gail Dolgin',
#     'Rebecca Cammisa and Julie Anderson',
#     'James Spione',
#     'Lucy Walker and Kira Carstensen']},
#   'Film Editing': {'winner_movie': 'The Girl with the Dragon Tattoo',
#    'winner_cast': 'Kirk Baxter and Angus Wall',
#    'nominees_movies': ['The Artist', 'The Descendants', 'Hugo', 'Moneyball'],
#    'nominees_cast': ['Anne-Sophie Bion and Michel Hazanavicius',
#     'Kevin Tent',
#     'Thelma Schoonmaker',
#     'Christopher Tellefsen']},
#   'Foreign Language Film': {'winner_movie': 'A Separation',
#    'winner_cast': 'Iran',
#    'nominees_movies': ['Bullhead',
#     'Footnote',
#     'In Darkness',
#     'Monsieur Lazhar'],
#    'nominees_cast': ['Belgium', 'Israel', 'Poland', 'Canada']},
#   'Makeup': {'winner_movie': 'The Iron Lady',
#    'winner_cast': 'Mark Coulier and J. Roy Helland',
#    'nominees_movies': ['Albert Nobbs',
#     'Harry Potter and the Deathly Hallows Part 2'],
#    'nominees_cast': ['Martial Corneville, Lynn Johnston and Matthew W. Mungle',
#     'Nick Dudman, Amanda Knight and Lisa Tomblin']},
#   'Music (Original Score)': {'winner_movie': 'The Artist',
#    'winner_cast': 'Ludovic Bource',
#    'nominees_movies': ['The Adventures of Tintin',
#     'Hugo',
#     'Tinker Tailor Soldier Spy',
#     'War Horse'],
#    'nominees_cast': ['John Williams',
#     'Howard Shore',
#     'Alberto Iglesias',
#     'John Williams']},
#   'Best Picture': {'winner_movie': 'The Artist',
#    'winner_cast': 'Thomas Langmann, Producer',
#    'nominees_movies': ['The Descendants',
#     'Extremely Loud & Incredibly Close',
#     'The Help',
#     'Hugo',
#     'Midnight in Paris',
#     'Moneyball',
#     'The Tree of Life',
#     'War Horse'],
#    'nominees_cast': ['Jim Burke, Alexander Payne and Jim Taylor, Producers',
#     'Scott Rudin, Producer',
#     'Brunson Green, Chris Columbus and Michael Barnathan, Producers',
#     'Graham King and Martin Scorsese, Producers',
#     'Letty Aronson and Stephen Tenenbaum, Producers',
#     'Michael De Luca, Rachael Horovitz and Brad Pitt, Producers',
#     'Sarah Green, Bill Pohlad, Dede Gardner and Grant Hill, Producers',
#     'Steven Spielberg and Kathleen Kennedy, Producers']},
#   'Short Film (Animated)': {'winner_movie': 'The Fantastic Flying Books of Mr. Morris Lessmore',
#    'winner_cast': 'William Joyce and Brandon Oldenburg',
#    'nominees_movies': ['Dimanche/Sunday',
#     'La Luna',
#     'A Morning Stroll',
#     'Wild Life'],
#    'nominees_cast': ['Patrick Doyon',
#     'Enrico Casarosa',
#     'Grant Orchard and Sue Goffe',
#     'Amanda Forbis and Wendy Tilby']},
#   'Short Film (Live Action)': {'winner_movie': 'The Shore',
#    'winner_cast': 'Terry George and Oorlagh George',
#    'nominees_movies': ['Pentecost', 'Raju', 'Time Freak'],
#    'nominees_cast': ["Peter McDonald and Eimear O'Kane",
#     'Max Zähle and Stefan Gieren',
#     'Andrew Bowler and Gigi Causey']},
#   'Sound Editing': {'winner_movie': 'Hugo',
#    'winner_cast': 'Philip Stockton and Eugene Gearty',
#    'nominees_movies': ['Drive',
#     'The Girl with the Dragon Tattoo',
#     'Transformers: Dark of the Moon',
#     'War Horse'],
#    'nominees_cast': ['Lon Bender and Victor Ray Ennis',
#     'Ren Klyce',
#     'Ethan Van der Ryn and Erik Aadahl',
#     'Richard Hymns and Gary Rydstrom']},
#   'Sound Mixing': {'winner_movie': 'Hugo',
#    'winner_cast': 'Tom Fleischman and John Midgley',
#    'nominees_movies': ['The Girl with the Dragon Tattoo',
#     'Moneyball',
#     'Transformers: Dark of the Moon',
#     'War Horse'],
#    'nominees_cast': ['David Parker, Michael Semanick, Ren Klyce and Bo Persson',
#     'Deb Adair, Ron Bochar, David Giammarco and Ed Novick',
#     'Greg P. Russell, Gary Summers, Jeffrey J. Haboush and Peter J. Devlin',
#     'Gary Rydstrom, Andy Nelson, Tom Johnson and Stuart Wilson']},
#   'Visual Effects': {'winner_movie': 'Hugo',
#    'winner_cast': 'Rob Legato, Joss Williams, Ben Grossmann and Alex Henning',
#    'nominees_movies': ['Harry Potter and the Deathly Hallows Part 2',
#     'Real Steel',
#     'Rise of the Planet of the Apes',
#     'Transformers: Dark of the Moon'],
#    'nominees_cast': ['Tim Burke, David Vickery, Greg Butler and John Richardson',
#     'Erik Nash, John Rosengrant, Dan Taylor and Swen Gillberg',
#     'Joe Letteri, Dan Lemmon, R. Christopher White and Daniel Barrett',
#     'Scott Farrar, Scott Benza, Matthew Butler and John Frazier']},
#   'Writing (Adapted Screenplay)': {'winner_movie': 'The Descendants',
#    'winner_cast': 'Screenplay by Alexander Payne and Nat Faxon & Jim Rash',
#    'nominees_movies': ['Hugo',
#     'The Ides of March',
#     'Moneyball',
#     'Tinker Tailor Soldier Spy'],
#    'nominees_cast': ['Screenplay by John Logan',
#     'Screenplay by George Clooney & Grant Heslov and Beau Willimon',
#     'Screenplay by Steven Zaillian and Aaron Sorkin; Story by Stan Chervin',
#     "Screenplay by Bridget O'Connor & Peter Straughan"]},
#   'Writing (Original Screenplay)': {'winner_movie': 'Midnight in Paris',
#    'winner_cast': 'Written by Woody Allen',
#    'nominees_movies': ['The Artist',
#     'Bridesmaids',
#     'Margin Call',
#     'A Separation'],
#    'nominees_cast': ['Written by Michel Hazanavicius',
#     'Written by Annie Mumolo & Kristen Wiig',
#     'Written by J.C. Chandor',
#     'Written by Asghar Farhadi']}},
#  2013: {'Actor in a Leading Role': {'winner_movie': 'Lincoln',
#    'winner_cast': 'Daniel Day-Lewis',
#    'nominees_movies': ['Silver Linings Playbook',
#     'Les Misérables',
#     'The Master',
#     'Flight'],
#    'nominees_cast': ['Bradley Cooper',
#     'Hugh Jackman',
#     'Joaquin Phoenix',
#     'Denzel Washington']},
#   'Actor in a Supporting Role': {'winner_movie': 'Django Unchained',
#    'winner_cast': 'Christoph Waltz',
#    'nominees_movies': ['Argo',
#     'Silver Linings Playbook',
#     'The Master',
#     'Lincoln'],
#    'nominees_cast': ['Alan Arkin',
#     'Robert De Niro',
#     'Philip Seymour Hoffman',
#     'Tommy Lee Jones']},
#   'Actress in a Leading Role': {'winner_movie': 'Silver Linings Playbook',
#    'winner_cast': 'Jennifer Lawrence',
#    'nominees_movies': ['Zero Dark Thirty',
#     'Amour',
#     'Beasts of the Southern Wild',
#     'The Impossible'],
#    'nominees_cast': ['Jessica Chastain',
#     'Emmanuelle Riva',
#     'Quvenzhané Wallis',
#     'Naomi Watts']},
#   'Actress in a Supporting Role': {'winner_movie': 'Les Misérables',
#    'winner_cast': 'Anne Hathaway',
#    'nominees_movies': ['The Master',
#     'Lincoln',
#     'The Sessions',
#     'Silver Linings Playbook'],
#    'nominees_cast': ['Amy Adams',
#     'Sally Field',
#     'Helen Hunt',
#     'Jacki Weaver']},
#   'Animated Feature Film': {'winner_movie': 'Brave',
#    'winner_cast': 'Mark Andrews and Brenda Chapman',
#    'nominees_movies': ['Frankenweenie',
#     'ParaNorman',
#     'The Pirates! Band of Misfits',
#     'Wreck-It Ralph'],
#    'nominees_cast': ['Tim Burton',
#     'Sam Fell and Chris Butler',
#     'Peter Lord',
#     'Rich Moore']},
#   'Cinematography': {'winner_movie': 'Life of Pi',
#    'winner_cast': 'Claudio Miranda',
#    'nominees_movies': ['Anna Karenina',
#     'Django Unchained',
#     'Lincoln',
#     'Skyfall'],
#    'nominees_cast': ['Seamus McGarvey',
#     'Robert Richardson',
#     'Janusz Kaminski',
#     'Roger Deakins']},
#   'Costume Design': {'winner_movie': 'Anna Karenina',
#    'winner_cast': 'Jacqueline Durran',
#    'nominees_movies': ['Les Mis_rables',
#     'Lincoln',
#     'Mirror Mirror',
#     'Snow White and the Huntsman'],
#    'nominees_cast': ['Paco Delgado',
#     'Joanna Johnston',
#     'Eiko Ishioka',
#     'Colleen Atwood']},
#   'Directing': {'winner_movie': 'Life of Pi',
#    'winner_cast': 'Ang Lee',
#    'nominees_movies': ['Amour',
#     'Beasts of the Southern Wild',
#     'Lincoln',
#     'Silver Linings Playbook'],
#    'nominees_cast': ['Michael Haneke',
#     'Benh Zeitlin',
#     'Steven Spielberg',
#     'David O. Russell']},
#   'Documentary (Feature)': {'winner_movie': 'Searching for Sugar Man',
#    'winner_cast': 'Malik Bendjelloul and Simon Chinn',
#    'nominees_movies': ['5 Broken Cameras',
#     'The Gatekeepers',
#     'How to Survive a Plague',
#     'The Invisible War'],
#    'nominees_cast': ['Emad Burnat and Guy Davidi',
#     'Dror Moreh, Philippa Kowarsky and Estelle Fialon',
#     'David France and Howard Gertler',
#     'Kirby Dick and Amy Ziering']},
#   'Documentary (Short Subject)': {'winner_movie': 'Inocente',
#    'winner_cast': 'Sean Fine and Andrea Nix Fine',
#    'nominees_movies': ['Kings Point',
#     'Mondays at Racine',
#     'Open Heart',
#     'Redemption'],
#    'nominees_cast': ['Sari Gilman and Jedd Wider',
#     'Cynthia Wade and Robin Honan',
#     'Kief Davidson and Cori Shepherd Stern',
#     "Jon Alpert and Matthew O'Neill"]},
#   'Film Editing': {'winner_movie': 'Argo',
#    'winner_cast': 'William Goldenberg',
#    'nominees_movies': ['Life of Pi',
#     'Lincoln',
#     'Silver Linings Playbook',
#     'Zero Dark Thirty'],
#    'nominees_cast': ['Tim Squyres',
#     'Michael Kahn',
#     'Jay Cassidy and Crispin Struthers',
#     'Dylan Tichenor and William Goldenberg']},
#   'Foreign Language Film': {'winner_movie': 'Amour',
#    'winner_cast': 'Austria',
#    'nominees_movies': ['Kon-Tiki', 'No', 'A Royal Affair', 'War Witch'],
#    'nominees_cast': ['Norway', 'Chile', 'Denmark', 'Canada']},
#   'Makeup and Hairstyling': {'winner_movie': 'Les Mis_rables',
#    'winner_cast': 'Lisa Westcott and Julie Dartnell',
#    'nominees_movies': ['Hitchcock', 'The Hobbit: An Unexpected Journey'],
#    'nominees_cast': ['Howard Berger, Peter Montagna and Martin Samuel',
#     'Peter Swords King, Rick Findlater and Tami Lane']},
#   'Music (Original Score)': {'winner_movie': 'Life of Pi',
#    'winner_cast': 'Mychael Danna',
#    'nominees_movies': ['Anna Karenina', 'Argo', 'Lincoln', 'Skyfall'],
#    'nominees_cast': ['Dario Marianelli',
#     'Alexandre Desplat',
#     'John Williams',
#     'Thomas Newman']},
#   'Best Picture': {'winner_movie': 'Argo',
#    'winner_cast': 'Grant Heslov, Ben Affleck and George Clooney, Producers',
#    'nominees_movies': ['Amour',
#     'Beasts of the Southern Wild',
#     'Django Unchained',
#     'Les Mis_rables',
#     'Life of Pi',
#     'Lincoln',
#     'Silver Linings Playbook',
#     'Zero Dark Thirty'],
#    'nominees_cast': ['Margaret Menegoz, Stefan Arndt, Veit Heiduschka and Michael Katz, Producers',
#     'Dan Janvey, Josh Penn and Michael Gottwald, Producers',
#     'Stacey Sher, Reginald Hudlin and Pilar Savone, Producers',
#     'Tim Bevan, Eric Fellner, Debra Hayward and Cameron Mackintosh, Producers',
#     'Gil Netter, Ang Lee and David Womark, Producers',
#     'Steven Spielberg and Kathleen Kennedy, Producers',
#     'Donna Gigliotti, Bruce Cohen and Jonathan Gordon, Producers',
#     'Mark Boal, Kathryn Bigelow and Megan Ellison, Producers']},
#   'Production Design': {'winner_movie': 'Lincoln',
#    'winner_cast': 'Production Design: Rick Carter; Set Decoration: Jim Erickson',
#    'nominees_movies': ['Anna Karenina',
#     'The Hobbit: An Unexpected Journey',
#     'Les Mis_rables',
#     'Life of Pi'],
#    'nominees_cast': ['Production Design: Sarah Greenwood; Set Decoration: Katie Spencer',
#     'Production Design: Dan Hennah; Set Decoration: Ra Vincent and Simon Bright',
#     'Production Design: Eve Stewart; Set Decoration: Anna Lynch-Robinson',
#     'Production Design: David Gropman; Set Decoration: Anna Pinnock']},
#   'Short Film (Animated)': {'winner_movie': 'Paperman',
#    'winner_cast': 'John Kahrs',
#    'nominees_movies': ['Adam and Dog',
#     'Fresh Guacamole',
#     'Head over Heels',
#     'Maggie Simpson in "The Longest Daycare"'],
#    'nominees_cast': ['Minkyu Lee',
#     'PES',
#     "Timothy Reckart and Fodhla Cronin O'Reilly",
#     'David Silverman']},
#   'Short Film (Live Action)': {'winner_movie': 'Curfew',
#    'winner_cast': 'Shawn Christensen',
#    'nominees_movies': ['Asad',
#     'Buzkashi Boys',
#     'Death of a Shadow (Dood van een Schaduw)',
#     'Henry'],
#    'nominees_cast': ['Bryan Buckley and Mino Jarjoura',
#     'Sam French and Ariel Nasr',
#     'Tom Van Avermaet and Ellen De Waele',
#     'Yan England']},
#   'Sound Editing': {'winner_movie': 'Skyfall',
#    'winner_cast': 'Per Hallberg and Karen Baker Landers',
#    'nominees_movies': ['Zero Dark Thirty',
#     'Argo',
#     'Django Unchained',
#     'Life of Pi'],
#    'nominees_cast': ['Paul N.J. Ottosson',
#     'Erik Aadahl and Ethan Van der Ryn',
#     'Wylie Stateman',
#     'Eugene Gearty and Philip Stockton']},
#   'Sound Mixing': {'winner_movie': 'Les Mis_rables',
#    'winner_cast': 'Andy Nelson, Mark Paterson and Simon Hayes',
#    'nominees_movies': ['Argo', 'Life of Pi', 'Lincoln', 'Skyfall'],
#    'nominees_cast': ['John Reitz, Gregg Rudloff and Jose Antonio Garcia',
#     'Ron Bartlett, D.M. Hemphill and Drew Kunin',
#     'Andy Nelson, Gary Rydstrom and Ronald Judkins',
#     'Scott Millan, Greg P. Russell and Stuart Wilson']},
#   'Visual Effects': {'winner_movie': 'Life of Pi',
#    'winner_cast': 'Bill Westenhofer, Guillaume Rocheron, Erik-Jan De Boer and Donald R. Elliott',
#    'nominees_movies': ['The Hobbit: An Unexpected Journey',
#     "Marvel's The Avengers",
#     'Prometheus',
#     'Snow White and the Huntsman'],
#    'nominees_cast': ['Joe Letteri, Eric Saindon, David Clayton and R. Christopher White',
#     'Janek Sirrs, Jeff White, Guy Williams and Dan Sudick',
#     'Richard Stammers, Trevor Wood, Charley Henley and Martin Hill',
#     'Cedric Nicolas-Troyan, Philip Brennan, Neil Corbould and Michael Dawson']},
#   'Writing (Adapted Screenplay)': {'winner_movie': 'Argo',
#    'winner_cast': 'Screenplay by Chris Terrio',
#    'nominees_movies': ['Beasts of the Southern Wild',
#     'Life of Pi',
#     'Lincoln',
#     'Silver Linings Playbook'],
#    'nominees_cast': ['Screenplay by Lucy Alibar & Benh Zeitlin',
#     'Screenplay by David Magee',
#     'Screenplay by Tony Kushner',
#     'Screenplay by David O. Russell']},
#   'Writing (Original Screenplay)': {'winner_movie': 'Django Unchained',
#    'winner_cast': 'Written by Quentin Tarantino',
#    'nominees_movies': ['Amour',
#     'Flight',
#     'Moonrise Kingdom',
#     'Zero Dark Thirty'],
#    'nominees_cast': ['Written by Michael Haneke',
#     'Written by John Gatins',
#     'Written by Wes Anderson & Roman Coppola',
#     'Written by Mark Boal']}},
#  2014: {'Actor in a Leading Role': {'winner_movie': 'Dallas Buyers Club',
#    'winner_cast': 'Matthew McConaughey',
#    'nominees_movies': ['American Hustle',
#     'Nebraska',
#     'The Wolf of Wall Street',
#     '12 Years a Slave'],
#    'nominees_cast': ['Christian Bale',
#     'Bruce Dern',
#     'Leonardo DiCaprio',
#     'Chiwetel Ejiofor']},
#   'Actor in a Supporting Role': {'winner_movie': 'Dallas Buyers Club',
#    'winner_cast': 'Jared Leto',
#    'nominees_movies': ['Captain Phillips',
#     'American Hustle',
#     '12 Years a Slave',
#     'The Wolf of Wall Street'],
#    'nominees_cast': ['Barkhad Abdi',
#     'Bradley Cooper',
#     'Michael Fassbender',
#     'Jonah Hill']},
#   'Actress in a Leading Role': {'winner_movie': 'Blue Jasmine',
#    'winner_cast': 'Cate Blanchett',
#    'nominees_movies': ['American Hustle',
#     'Gravity',
#     'Philomena',
#     'August: Osage County'],
#    'nominees_cast': ['Amy Adams',
#     'Sandra Bullock',
#     'Judi Dench',
#     'Meryl Streep']},
#   'Actress in a Supporting Role': {'winner_movie': '12 Years a Slave',
#    'winner_cast': "Lupita Nyong'o",
#    'nominees_movies': ['Blue Jasmine',
#     'American Hustle',
#     'August: Osage County',
#     'Nebraska'],
#    'nominees_cast': ['Sally Hawkins',
#     'Jennifer Lawrence',
#     'Julia Roberts',
#     'June Squibb']},
#   'Animated Feature Film': {'winner_movie': 'Frozen',
#    'winner_cast': 'Chris Buck, Jennifer Lee and Peter Del Vecho',
#    'nominees_movies': ['The Croods',
#     'Despicable Me 2',
#     'Ernest & Celestine',
#     'The Wind Rises'],
#    'nominees_cast': ['Chris Sanders, Kirk DeMicco and Kristine Belson',
#     'Chris Renaud, Pierre Coffin and Chris Meledandri',
#     'Benjamin Renner and Didier Brunner',
#     'Hayao Miyazaki and Toshio Suzuki']},
#   'Cinematography': {'winner_movie': 'Gravity',
#    'winner_cast': 'Emmanuel Lubezki',
#    'nominees_movies': ['The Grandmaster',
#     'Inside Llewyn Davis',
#     'Nebraska',
#     'Prisoners'],
#    'nominees_cast': ['Philippe Le Sourd',
#     'Bruno Delbonnel',
#     'Phedon Papamichael',
#     'Roger A. Deakins']},
#   'Costume Design': {'winner_movie': 'The Great Gatsby',
#    'winner_cast': 'Catherine Martin',
#    'nominees_movies': ['American Hustle',
#     'The Grandmaster',
#     'The Invisible Woman',
#     '12 Years a Slave'],
#    'nominees_cast': ['Michael Wilkinson',
#     'William Chang Suk Ping',
#     "Michael O'Connor",
#     'Patricia Norris']},
#   'Directing': {'winner_movie': 'Gravity',
#    'winner_cast': 'Alfonso Cuarón',
#    'nominees_movies': ['American Hustle',
#     'Nebraska',
#     '12 Years a Slave',
#     'The Wolf of Wall Street'],
#    'nominees_cast': ['David O. Russell',
#     'Alexander Payne',
#     'Steve McQueen',
#     'Martin Scorsese']},
#   'Documentary (Feature)': {'winner_movie': '20 Feet from Stardom',
#    'winner_cast': 'Morgan Neville, Gil Friesen and Caitrin Rogers',
#    'nominees_movies': ['The Act of Killing',
#     'Cutie and the Boxer',
#     'Dirty Wars',
#     'The Square'],
#    'nominees_cast': ['Joshua Oppenheimer and Signe Byrge Sørensen',
#     'Zachary Heinzerling and Lydia Dean Pilcher',
#     'Richard Rowley and Jeremy Scahill',
#     'Jehane Noujaim and Karim Amer']},
#   'Documentary (Short Subject)': {'winner_movie': 'The Lady in Number 6: Music Saved My Life',
#    'winner_cast': 'Malcolm Clarke and Nicholas Reed',
#    'nominees_movies': ['CaveDigger',
#     'Facing Fear',
#     'Karama Has No Walls',
#     'Prison Terminal: The Last Days of Private Jack Hall'],
#    'nominees_cast': ['Jeffrey Karoff',
#     'Jason Cohen',
#     'Sara Ishaq',
#     'Edgar Barens']},
#   'Film Editing': {'winner_movie': 'Gravity',
#    'winner_cast': 'Alfonso Cuarón and Mark Sanger',
#    'nominees_movies': ['American Hustle',
#     'Captain Phillips',
#     'Dallas Buyers Club',
#     '12 Years a Slave'],
#    'nominees_cast': ['Jay Cassidy, Crispin Struthers and Alan Baumgarten',
#     'Christopher Rouse',
#     'John Mac McMurphy and Martin Pensa',
#     'Joe Walker']},
#   'Foreign Language Film': {'winner_movie': 'The Great Beauty',
#    'winner_cast': 'Italy',
#    'nominees_movies': ['The Broken Circle Breakdown',
#     'The Hunt',
#     'The Missing Picture',
#     'Omar'],
#    'nominees_cast': ['Belgium', 'Denmark', 'Cambodia', 'Palestine']},
#   'Makeup and Hairstyling': {'winner_movie': 'Dallas Buyers Club',
# ...
#    'nominees_cast': ['Shaunak Sen, Aman Mann and Teddy Leifer',
#     'Laura Poitras, Howard Gertler, John Lyons, Nan Goldin and Yoni Golijov',
#     'Sara Dosa, Shane Boris and Ina Fichman',
#     'Simon Lereng Wilmont and Monica Hellström']},
#   'Documentary Short Film': {'winner_movie': 'The Elephant Whisperers',
#    'winner_cast': 'Kartiki Gonsalves and Guneet Monga',
#    'nominees_movies': ['Haulout',
#     'How Do You Measure a Year?',
#     'The Martha Mitchell Effect',
#     'Stranger at the Gate'],
#    'nominees_cast': ['Evgenia Arbugaeva and Maxim Arbugaev',
#     'Jay Rosenblatt',
#     'Anne Alvergue and Beth Levison',
#     'Joshua Seftel and Conall Jones']},
#   'Film Editing': {'winner_movie': 'Everything Everywhere All at Once',
#    'winner_cast': 'Paul Rogers',
#    'nominees_movies': ['The Banshees of Inisherin',
#     'Elvis',
#     'Tár',
#     'Top Gun: Maverick'],
#    'nominees_cast': ['Mikkel E.G. Nielsen',
#     'Matt Villa and Jonathan Redmond',
#     'Monika Willi',
#     'Eddie Hamilton']},
#   'International Feature Film': {'winner_movie': 'All Quiet on the Western Front',
#    'winner_cast': 'Germany',
#    'nominees_movies': ['Argentina, 1985', 'Close', 'EO', 'The Quiet Girl'],
#    'nominees_cast': ['Argentina', 'Belgium', 'Poland', 'Ireland']},
#   'Makeup and Hairstyling': {'winner_movie': 'The Whale',
#    'winner_cast': 'Adrien Morot, Judy Chin and Annemarie Bradley',
#    'nominees_movies': ['All Quiet on the Western Front',
#     'The Batman',
#     'Black Panther: Wakanda Forever',
#     'Elvis'],
#    'nominees_cast': ['Heike Merker and Linda Eisenhamerová',
#     'Naomi Donne, Mike Marino and Mike Fontaine',
#     'Camille Friend and Joel Harlow',
#     'Mark Coulier, Jason Baird and Aldo Signoretti']},
#   'Music (Original Score)': {'winner_movie': 'All Quiet on the Western Front',
#    'winner_cast': 'Volker Bertelmann',
#    'nominees_movies': ['Babylon',
#     'The Banshees of Inisherin',
#     'Everything Everywhere All at Once',
#     'The Fabelmans'],
#    'nominees_cast': ['Justin Hurwitz',
#     'Carter Burwell',
#     'Son Lux',
#     'John Williams']},
#   'Best Picture': {'winner_movie': 'Everything Everywhere All at Once',
#    'winner_cast': 'Daniel Kwan, Daniel Scheinert and Jonathan Wang, Producers',
#    'nominees_movies': ['All Quiet on the Western Front',
#     'Avatar: The Way of Water',
#     'The Banshees of Inisherin',
#     'Elvis',
#     'The Fabelmans',
#     'Tár',
#     'Top Gun: Maverick',
#     'Triangle of Sadness',
#     'Women Talking'],
#    'nominees_cast': ['Malte Grunert, Producer',
#     'James Cameron and Jon Landau, Producers',
#     'Graham Broadbent, Pete Czernin and Martin McDonagh, Producers',
#     'Baz Luhrmann, Catherine Martin, Gail Berman, Patrick McCormick and Schuyler Weiss, Producers',
#     'Kristie Macosko Krieger, Steven Spielberg and Tony Kushner, Producers',
#     'Todd Field, Alexandra Milchan and Scott Lambert, Producers',
#     'Tom Cruise, Christopher McQuarrie, David Ellison and Jerry Bruckheimer, Producers',
#     'Erik Hemmendorff and Philippe Bober, Producers',
#     'Dede Gardner, Jeremy Kleiner and Frances McDormand, Producers']},
#   'Production Design': {'winner_movie': 'All Quiet on the Western Front',
#    'winner_cast': 'Production Design: Christian M. Goldbeck; Set Decoration: Ernestine Hipper',
#    'nominees_movies': ['Avatar: The Way of Water',
#     'Babylon',
#     'Elvis',
#     'The Fabelmans'],
#    'nominees_cast': ['Production Design: Dylan Cole and Ben Procter; Set Decoration: Vanessa Cole',
#     'Production Design: Florencia Martin; Set Decoration: Anthony Carlino',
#     'Production Design: Catherine Martin and Karen Murphy; Set Decoration: Bev Dunn',
#     "Production Design: Rick Carter; Set Decoration: Karen O'Hara"]},
#   'Short Film (Animated)': {'winner_movie': 'The Boy, the Mole, the Fox and the Horse',
#    'winner_cast': 'Charlie Mackesy and Matthew Freud',
#    'nominees_movies': ['The Flying Sailor',
#     'Ice Merchants',
#     'My Year of Dicks',
#     'An Ostrich Told Me the World Is Fake and I Think I Believe It'],
#    'nominees_cast': ['Amanda Forbis and Wendy Tilby',
#     'João Gonzalez and Bruno Caetano',
#     'Sara Gunnarsdóttir and Pamela Ribon',
#     'Lachlan Pendragon']},
#   'Short Film (Live Action)': {'winner_movie': 'An Irish Goodbye',
#    'winner_cast': 'Tom Berkeley and Ross White',
#    'nominees_movies': ['Ivalu',
#     'Le Pupille',
#     'Night Ride',
#     'The Red Suitcase'],
#    'nominees_cast': ['Anders Walter and Rebecca Pruzan',
#     'Alice Rohrwacher and Alfonso Cuarón',
#     'Eirik Tveiten and Gaute Lid Larssen',
#     'Cyrus Neshvad']},
#   'Sound': {'winner_movie': 'Top Gun: Maverick',
#    'winner_cast': 'Mark Weingarten, James H. Mather, Al Nelson, Chris Burdon and Mark Taylor',
#    'nominees_movies': ['All Quiet on the Western Front',
#     'Avatar: The Way of Water',
#     'The Batman',
#     'Elvis'],
#    'nominees_cast': ['Viktor Prášil, Frank Kruse, Markus Stemler, Lars Ginzel and Stefan Korte',
#     'Julian Howarth, Gwendolyn Yates Whittle, Dick Bernstein, Christopher Boyes, Gary Summers and Michael Hedges',
#     'Stuart Wilson, William Files, Douglas Murray and Andy Nelson',
#     'David Lee, Wayne Pashley, Andy Nelson and Michael Keller']},
#   'Visual Effects': {'winner_movie': 'Avatar: The Way of Water',
#    'winner_cast': 'Joe Letteri, Richard Baneham, Eric Saindon and Daniel Barrett',
#    'nominees_movies': ['All Quiet on the Western Front',
#     'The Batman',
#     'Black Panther: Wakanda Forever',
#     'Top Gun: Maverick'],
#    'nominees_cast': ['Frank Petzold, Viktor Müller, Markus Frank and Kamil Jafar',
#     'Dan Lemmon, Russell Earl, Anders Langlands and Dominic Tuohy',
#     'Geoffrey Baumann, Craig Hammack, R. Christopher White and Dan Sudick',
#     'Ryan Tudhope, Seth Hill, Bryan Litson and Scott R. Fisher']},
#   'Writing (Adapted Screenplay)': {'winner_movie': 'Women Talking',
#    'winner_cast': 'Screenplay by Sarah Polley',
#    'nominees_movies': ['All Quiet on the Western Front',
#     'Glass Onion: A Knives Out Mystery',
#     'Living',
#     'Top Gun: Maverick'],
#    'nominees_cast': ['Screenplay - Edward Berger, Lesley Paterson & Ian Stokell',
#     'Written by Rian Johnson',
#     'Written by Kazuo Ishiguro',
#     'Screenplay by Ehren Kruger and Eric Warren Singer and Christopher McQuarrie; Story by Peter Craig and Justin Marks']},
#   'Writing (Original Screenplay)': {'winner_movie': 'Everything Everywhere All at Once',
#    'winner_cast': 'Written by Daniel Kwan & Daniel Scheinert',
#    'nominees_movies': ['The Banshees of Inisherin',
#     'The Fabelmans',
#     'Tár',
#     'Triangle of Sadness'],
#    'nominees_cast': ['Written by Martin McDonagh',
#     'Written by Steven Spielberg & Tony Kushner',
#     'Written by Todd Field',
#     'Written by Ruben Östlund']}},
#  2024: {'Actor in a Leading Role': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Cillian Murphy',
#    'nominees_movies': ['Maestro',
#     'Rustin',
#     'The Holdovers',
#     'American Fiction'],
#    'nominees_cast': ['Bradley Cooper',
#     'Colman Domingo',
#     'Paul Giamatti',
#     'Jeffrey Wright']},
#   'Actor in a Supporting Role': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Robert Downey Jr.',
#    'nominees_movies': ['American Fiction',
#     'Killers of the Flower Moon',
#     'Barbie',
#     'Poor Things'],
#    'nominees_cast': ['Sterling K. Brown',
#     'Robert De Niro',
#     'Ryan Gosling',
#     'Mark Ruffalo']},
#   'Actress in a Leading Role': {'winner_movie': 'Poor Things',
#    'winner_cast': 'Emma Stone',
#    'nominees_movies': ['Nyad',
#     'Killers of the Flower Moon',
#     'Anatomy of a Fall',
#     'Maestro'],
#    'nominees_cast': ['Annette Bening',
#     'Lily Gladstone',
#     'Sandra Hüller',
#     'Carey Mulligan']},
#   'Actress in a Supporting Role': {'winner_movie': 'The Holdovers',
#    'winner_cast': "Da'Vine Joy Randolph",
#    'nominees_movies': ['Oppenheimer', 'The Color Purple', 'Barbie', 'Nyad'],
#    'nominees_cast': ['Emily Blunt',
#     'Danielle Brooks',
#     'America Ferrera',
#     'Jodie Foster']},
#   'Animated Feature Film': {'winner_movie': 'The Boy and the Heron',
#    'winner_cast': 'Hayao Miyazaki and Toshio Suzuki',
#    'nominees_movies': ['Elemental',
#     'Nimona',
#     'Robot Dreams',
#     'Spider-Man: Across the Spider-Verse'],
#    'nominees_cast': ['Peter Sohn and Denise Ream',
#     'Nick Bruno, Troy Quane, Karen Ryan and Julie Zackary',
#     'Pablo Berger, Ibon Cormenzana, Ignasi Estapé and Sandra Tapia Díaz',
#     'Kemp Powers, Justin K. Thompson, Phil Lord, Christopher Miller and Amy Pascal']},
#   'Cinematography': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Hoyte van Hoytema',
#    'nominees_movies': ['El Conde',
#     'Killers of the Flower Moon',
#     'Maestro',
#     'Poor Things'],
#    'nominees_cast': ['Edward Lachman',
#     'Rodrigo Prieto',
#     'Matthew Libatique',
#     'Robbie Ryan']},
#   'Costume Design': {'winner_movie': 'Poor Things',
#    'winner_cast': 'Holly Waddington',
#    'nominees_movies': ['Barbie',
#     'Killers of the Flower Moon',
#     'Napoleon',
#     'Oppenheimer'],
#    'nominees_cast': ['Jacqueline Durran',
#     'Jacqueline West',
#     'Janty Yates and Dave Crossman',
#     'Ellen Mirojnick']},
#   'Directing': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Christopher Nolan',
#    'nominees_movies': ['Anatomy of a Fall',
#     'Killers of the Flower Moon',
#     'Poor Things',
#     'The Zone of Interest'],
#    'nominees_cast': ['Justine Triet',
#     'Martin Scorsese',
#     'Yorgos Lanthimos',
#     'Jonathan Glazer']},
#   'Documentary Feature Film': {'winner_movie': '20 Days in Mariupol',
#    'winner_cast': 'Mstyslav Chernov, Michelle Mizner and Raney Aronson-Rath',
#    'nominees_movies': ["Bobi Wine: The People's President",
#     'The Eternal Memory',
#     'Four Daughters',
#     'To Kill a Tiger'],
#    'nominees_cast': ['Moses Bwayo, Christopher Sharp and John Battsek',
#     'Maite Alberdi',
#     'Kaouther Ben Hania and Nadim Cheikhrouha',
#     'Nisha Pahuja, Cornelia Principe and David Oppenheim']},
#   'Documentary Short Film': {'winner_movie': 'The Last Repair Shop',
#    'winner_cast': 'Ben Proudfoot and Kris Bowers',
#    'nominees_movies': ['The ABCs of Book Banning',
#     'The Barber of Little Rock',
#     'Island in Between',
#     'Nǎi Nai & Wài Pó'],
#    'nominees_cast': ['Sheila Nevins and Trish Adlesic',
#     'John Hoffman and Christine Turner',
#     'S. Leo Chiang and Jean Tsien',
#     'Sean Wang and Sam Davis']},
#   'Film Editing': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Jennifer Lame',
#    'nominees_movies': ['Anatomy of a Fall',
#     'The Holdovers',
#     'Killers of the Flower Moon',
#     'Poor Things'],
#    'nominees_cast': ['Laurent Sénéchal',
#     'Kevin Tent',
#     'Thelma Schoonmaker',
#     'Yorgos Mavropsaridis']},
#   'International Feature Film': {'winner_movie': 'The Zone of Interest',
#    'winner_cast': 'United Kingdom',
#    'nominees_movies': ['Io Capitano',
#     'Perfect Days',
#     'Society of the Snow',
#     "The Teachers' Lounge"],
#    'nominees_cast': ['Italy', 'Japan', 'Spain', 'Germany']},
#   'Makeup and Hairstyling': {'winner_movie': 'Poor Things',
#    'winner_cast': 'Nadia Stacey, Mark Coulier and Josh Weston',
#    'nominees_movies': ['Golda',
#     'Maestro',
#     'Oppenheimer',
#     'Society of the Snow'],
#    'nominees_cast': ['Karen Hartley Thomas, Suzi Battersby and Ashra Kelly-Blue',
#     'Kazu Hiro, Kay Georgiou and Lori McCoy-Bell',
#     'Luisa Abel',
#     'Ana López-Puigcerver, David Martí and Montse Ribé']},
#   'Music (Original Score)': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Ludwig Göransson',
#    'nominees_movies': ['American Fiction',
#     'Indiana Jones and the Dial of Destiny',
#     'Killers of the Flower Moon',
#     'Poor Things'],
#    'nominees_cast': ['Laura Karpman',
#     'John Williams',
#     'Robbie Robertson',
#     'Jerskin Fendrix']},
#   'Best Picture': {'winner_movie': 'Oppenheimer',
#    'winner_cast': 'Emma Thomas, Charles Roven and Christopher Nolan, Producers',
#    'nominees_movies': ['American Fiction',
#     'Anatomy of a Fall',
#     'Barbie',
#     'The Holdovers',
#     'Killers of the Flower Moon',
#     'Maestro',
#     'Past Lives',
#     'Poor Things',
#     'The Zone of Interest'],
#    'nominees_cast': ['Ben LeClair, Nikos Karamigios, Cord Jefferson and Jermaine Johnson, Producers',
#     'Marie-Ange Luciani and David Thion, Producers',
#     'David Heyman, Margot Robbie, Tom Ackerley and Robbie Brenner, Producers',
#     'Mark Johnson, Producer',
#     'Dan Friedkin, Bradley Thomas, Martin Scorsese and Daniel Lupi, Producers',
#     'Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning and Kristie Macosko Krieger, Producers',
#     'David Hinojosa, Christine Vachon and Pamela Koffler, Producers',
#     'Ed Guiney, Andrew Lowe, Yorgos Lanthimos and Emma Stone, Producers',
#     'James Wilson, Producer']},
#   'Production Design': {'winner_movie': 'Poor Things',
#    'winner_cast': 'Production Design: James Price and Shona Heath; Set Decoration: Zsuzsa Mihalek',
#    'nominees_movies': ['Barbie',
#     'Killers of the Flower Moon',
#     'Napoleon',
#     'Oppenheimer'],
#    'nominees_cast': ['Production Design: Sarah Greenwood; Set Decoration: Katie Spencer',
#     'Production Design: Jack Fisk; Set Decoration: Adam Willis',
#     'Production Design: Arthur Max; Set Decoration: Elli Griff',
#     'Production Design: Ruth De Jong; Set Decoration: Claire Kaufman']},
#   'Animated Short Film': {'winner_movie': 'WAR IS OVER! Inspired by the Music of John & Yoko',
#    'winner_cast': 'Dave Mullins and Brad Booker',
#    'nominees_movies': ['Letter to a Pig',
#     'Ninety-Five Senses',
#     'Our Uniform',
#     'Pachyderme'],
#    'nominees_cast': ['Tal Kantor and Amit R. Gicelter',
#     'Jerusha Hess and Jared Hess',
#     'Yegane Moghaddam',
#     'Stéphanie Clément and Marc Rius']},
#   'Live Action Short Film': {'winner_movie': 'The Wonderful Story of Henry Sugar',
#    'winner_cast': 'Wes Anderson and Steven Rales',
#    'nominees_movies': ['The After',
#     'Invincible',
#     'Knight of Fortune',
#     'Red, White and Blue'],
#    'nominees_cast': ['Misan Harriman and Nicky Bentham',
#     'Vincent René-Lortie and Samuel Caron',
#     'Lasse Lyskjær Noer and Christian Norlyk',
#     'Nazrin Choudhury and Sara McFarlane']},
#   'Sound': {'winner_movie': 'The Zone of Interest',
#    'winner_cast': 'Tarn Willers and Johnnie Burn',
#    'nominees_movies': ['The Creator',
#     'Maestro',
#     'Mission: Impossible - Dead Reckoning Part One',
#     'Oppenheimer'],
#    'nominees_cast': ['Ian Voigt, Erik Aadahl, Ethan Van der Ryn, Tom Ozanich and Dean Zupancic',
#     'Steven A. Morrow, Richard King, Jason Ruder, Tom Ozanich and Dean Zupancic',
#     'Chris Munro, James H. Mather, Chris Burdon and Mark Taylor',
#     "Willie Burton, Richard King, Gary A. Rizzo and Kevin O'Connell"]},
#   'Visual Effects': {'winner_movie': 'Godzilla Minus One',
#    'winner_cast': 'Takashi Yamazaki, Kiyoko Shibuya, Masaki Takahashi and Tatsuji Nojima',
#    'nominees_movies': ['The Creator',
#     'Guardians of the Galaxy Vol. 3',
#     'Mission: Impossible - Dead Reckoning Part One',
#     'Napoleon'],
#    'nominees_cast': ['Jay Cooper, Ian Comley, Andrew Roberts and Neil Corbould',
#     'Stephane Ceretti, Alexis Wajsbrot, Guy Williams and Theo Bialek',
#     'Alex Wuttke, Simone Coco, Jeff Sutherland and Neil Corbould',
#     'Charley Henley, Luc-Ewen Martin-Fenouillet, Simone Coco and Neil Corbould']},
#   'Writing (Adapted Screenplay)': {'winner_movie': 'American Fiction',
#    'winner_cast': 'Written for the screen by Cord Jefferson',
#    'nominees_movies': ['Barbie',
#     'Oppenheimer',
#     'Poor Things',
#     'The Zone of Interest'],
#    'nominees_cast': ['Written by Greta Gerwig & Noah Baumbach',
#     'Written for the screen by Christopher Nolan',
#     'Screenplay by Tony McNamara',
#     'Written by Jonathan Glazer']},
#   'Writing (Original Screenplay)': {'winner_movie': 'Anatomy of a Fall',
#    'winner_cast': 'Screenplay - Justine Triet and Arthur Harari',
#    'nominees_movies': ['The Holdovers',
#     'Maestro',
#     'May December',
#     'Past Lives'],
#    'nominees_cast': ['Written by David Hemingson',
#     'Written by Bradley Cooper & Josh Singer',
#     'Screenplay by Samy Burch; Story by Samy Burch & Alex Mechanik',
#     'Written by Celine Song']}}}

# %% [markdown]
# ## Create Dataframe With All Awards data

# %%
# Make a unique list of all the movies that have been nominated or won an Oscar
unique_movies = set()
for year, ceremony in all_oscars_awards.items():
    for category, awardess in ceremony.items():
        # Add the winner and the nominees to the set
        unique_movies.update([awardess["winner_movie"]]) # <-- IMPURITY #11: Only one winner, so make it a list
        unique_movies.update(awardess["nominees_movies"])
unique_movies = sorted(unique_movies, key=lambda x: x.lower())

# Now create the dataframe
df_awards = pd.DataFrame(columns=["Movie Title", "Oscar Ceremony Year", "Cast Involved"] + all_categories,
                         index=range(len(unique_movies)))
df_awards["Movie Title"] = unique_movies

# %%
all_oscars_awards

# %%
df_awards.sample(5)
# Out:
#                     Movie Title Oscar Ceremony Year Cast Involved  \
# 340           Island in Between                 NaN           NaN
# 155          Coco before Chanel                 NaN           NaN
# 83                          Aya                 NaN           NaN
# 46   All the Money in the World                 NaN           NaN
# 571                        Shok                 NaN           NaN
#
#     Actor in a Leading Role Actor in a Supporting Role  \
# 340                     NaN                        NaN
# 155                     NaN                        NaN
# 83                      NaN                        NaN
# 46                      NaN                        NaN
# 571                     NaN                        NaN
#
#     Actress in a Leading Role Actress in a Supporting Role  \
# 340                       NaN                          NaN
# 155                       NaN                          NaN
# 83                        NaN                          NaN
# 46                        NaN                          NaN
# 571                       NaN                          NaN
#
#     Animated Feature Film Animated Short Film Art Direction Best Picture  \
# 340                   NaN                 NaN           NaN          NaN
# 155                   NaN                 NaN           NaN          NaN
# 83                    NaN                 NaN           NaN          NaN
# 46                    NaN                 NaN           NaN          NaN
# 571                   NaN                 NaN           NaN          NaN
#
#     Cinematography Costume Design Directing Documentary (Feature)  \
# 340            NaN            NaN       NaN                   NaN
# 155            NaN            NaN       NaN                   NaN
# 83             NaN            NaN       NaN                   NaN
# 46             NaN            NaN       NaN                   NaN
# 571            NaN            NaN       NaN                   NaN
#
#     Documentary (Short Subject) Documentary Feature Film  \
# 340                         NaN                      NaN
# 155                         NaN                      NaN
# 83                          NaN                      NaN
# 46                          NaN                      NaN
# 571                         NaN                      NaN
#
#     Documentary Short Film Film Editing Foreign Language Film  \
# 340                    NaN          NaN                   NaN
# 155                    NaN          NaN                   NaN
# 83                     NaN          NaN                   NaN
# 46                     NaN          NaN                   NaN
# 571                    NaN          NaN                   NaN
#
#     International Feature Film Irving G. Thalberg Memorial Award  \
# 340                        NaN                               NaN
# 155                        NaN                               NaN
# 83                         NaN                               NaN
# 46                         NaN                               NaN
# 571                        NaN                               NaN
#
#     Jean Hersholt Humanitarian Award Live Action Short Film Makeup  \
# 340                              NaN                    NaN    NaN
# 155                              NaN                    NaN    NaN
# 83                               NaN                    NaN    NaN
# 46                               NaN                    NaN    NaN
# 571                              NaN                    NaN    NaN
#
#     Makeup and Hairstyling Music (Original Score) Music (Original Song)  \
# 340                    NaN                    NaN                   NaN
# 155                    NaN                    NaN                   NaN
# 83                     NaN                    NaN                   NaN
# 46                     NaN                    NaN                   NaN
# 571                    NaN                    NaN                   NaN
#
#     Production Design Short Film (Animated) Short Film (Live Action) Sound  \
# 340               NaN                   NaN                      NaN   NaN
# 155               NaN                   NaN                      NaN   NaN
# 83                NaN                   NaN                      NaN   NaN
# 46                NaN                   NaN                      NaN   NaN
# 571               NaN                   NaN                      NaN   NaN
#
#     Sound Editing Sound Mixing Visual Effects Writing (Adapted Screenplay)  \
# 340           NaN          NaN            NaN                          NaN
# 155           NaN          NaN            NaN                          NaN
# 83            NaN          NaN            NaN                          NaN
# 46            NaN          NaN            NaN                          NaN
# 571           NaN          NaN            NaN                          NaN
#
#     Writing (Original Screenplay)
# 340                           NaN
# 155                           NaN
# 83                            NaN
# 46                            NaN
# 571                           NaN

# %%
# Iterate over the years and the categories to fill the boolean of Winner and Nominated
for year, ceremony in all_oscars_awards.items():
    for category, awardess in ceremony.items():
        # WINNERS
        # Get Boolean column if the movie is a winner or not
        movie_title_name = df_awards["Movie Title"] == awardess["winner_movie"]
        # Add the year of the ceremony
        df_awards.loc[movie_title_name, "Oscar Ceremony Year"] = year
        # Add the cast involved
        df_awards.loc[movie_title_name, "Cast Involved"] = df_awards.loc[movie_title_name, "Cast Involved"].apply(
    lambda x: x + ", " + awardess["winner_cast"] if pd.notna(x) else awardess["winner_cast"] # <-- IMPURITY #12: Ignore NAs as they cause errors
)
        # Specify the boolean Winner for the category won
        df_awards.loc[movie_title_name, category] = "Winner"

        for nominees_movie, nominees_cast in zip(awardess["nominees_movies"], awardess["nominees_cast"]):
            # NOMINEES
            # Get Boolean column if the movie is nominated or not
            movie_title_name = df_awards["Movie Title"] == nominees_movie
            # Add the year of the ceremony
            df_awards.loc[movie_title_name, "Oscar Ceremony Year"] = year
            # Add the cast involved
            df_awards.loc[movie_title_name, "Cast Involved"] = df_awards.loc[movie_title_name, "Cast Involved"].apply(
                lambda x: x + ", " + nominees_cast if pd.notna(x) else nominees_cast
            )
            # Specify the boolean Nominated for the category nominated
            df_awards.loc[movie_title_name, category] = "Nominated"

# %%
df_awards.sample(10)
# Out:
#                        Movie Title Oscar Ceremony Year  \
# 692             The Imitation Game                2015
# 417          Manchester by the Sea                2017
# 183                     Departures                2009
# 392                     Life of Pi                2013
# 476                 No Time To Die                2022
# 495  Outside the Law (Hors-la-loi)                2011
# 714            The Look of Silence                2016
# 854                    Wolfwalkers                2021
# 80                       Ave Maria                2016
# 218                       Extremis                2017
#
#                                          Cast Involved  \
# 692  Benedict Cumberbatch, Keira Knightley, Morten ...
# 417  Casey Affleck, Lucas Hedges, Michelle Williams...
# 183                                              Japan
# 392  Claudio Miranda, Ang Lee, Tim Squyres, Mychael...
# 476  Simon Hayes, Oliver Tarney, James Harrison, Pa...
# 495                                            Algeria
# 714        Joshua Oppenheimer and Signe Byrge Sørensen
# 854  Tomm Moore, Ross Stewart, Paul Young and Stéph...
# 80                        Basil Khalil and Eric Dupont
# 218                                         Dan Krauss
#
#     Actor in a Leading Role Actor in a Supporting Role  \
# 692               Nominated                        NaN
# 417                  Winner                  Nominated
# 183                     NaN                        NaN
# 392                     NaN                        NaN
# 476                     NaN                        NaN
# 495                     NaN                        NaN
# 714                     NaN                        NaN
# 854                     NaN                        NaN
# 80                      NaN                        NaN
# 218                     NaN                        NaN
#
#     Actress in a Leading Role Actress in a Supporting Role  \
# 692                       NaN                    Nominated
# 417                       NaN                    Nominated
# 183                       NaN                          NaN
# 392                       NaN                          NaN
# 476                       NaN                          NaN
# 495                       NaN                          NaN
# 714                       NaN                          NaN
# 854                       NaN                          NaN
# 80                        NaN                          NaN
# 218                       NaN                          NaN
#
#     Animated Feature Film Animated Short Film Art Direction Best Picture  \
# 692                   NaN                 NaN           NaN    Nominated
# 417                   NaN                 NaN           NaN    Nominated
# 183                   NaN                 NaN           NaN          NaN
# 392                   NaN                 NaN           NaN    Nominated
# 476                   NaN                 NaN           NaN          NaN
# 495                   NaN                 NaN           NaN          NaN
# 714                   NaN                 NaN           NaN          NaN
# 854             Nominated                 NaN           NaN          NaN
# 80                    NaN                 NaN           NaN          NaN
# 218                   NaN                 NaN           NaN          NaN
#
#     Cinematography Costume Design  Directing Documentary (Feature)  \
# 692            NaN            NaN  Nominated                   NaN
# 417            NaN            NaN  Nominated                   NaN
# 183            NaN            NaN        NaN                   NaN
# 392         Winner            NaN     Winner                   NaN
# 476            NaN            NaN        NaN                   NaN
# 495            NaN            NaN        NaN                   NaN
# 714            NaN            NaN        NaN             Nominated
# 854            NaN            NaN        NaN                   NaN
# 80             NaN            NaN        NaN                   NaN
# 218            NaN            NaN        NaN                   NaN
#
#     Documentary (Short Subject) Documentary Feature Film  \
# 692                         NaN                      NaN
# 417                         NaN                      NaN
# 183                         NaN                      NaN
# 392                         NaN                      NaN
# 476                         NaN                      NaN
# 495                         NaN                      NaN
# 714                         NaN                      NaN
# 854                         NaN                      NaN
# 80                          NaN                      NaN
# 218                   Nominated                      NaN
#
#     Documentary Short Film Film Editing Foreign Language Film  \
# 692                    NaN    Nominated                   NaN
# 417                    NaN          NaN                   NaN
# 183                    NaN          NaN                Winner
# 392                    NaN    Nominated                   NaN
# 476                    NaN          NaN                   NaN
# 495                    NaN          NaN             Nominated
# 714                    NaN          NaN                   NaN
# 854                    NaN          NaN                   NaN
# 80                     NaN          NaN                   NaN
# 218                    NaN          NaN                   NaN
#
#     International Feature Film Irving G. Thalberg Memorial Award  \
# 692                        NaN                               NaN
# 417                        NaN                               NaN
# 183                        NaN                               NaN
# 392                        NaN                               NaN
# 476                        NaN                               NaN
# 495                        NaN                               NaN
# 714                        NaN                               NaN
# 854                        NaN                               NaN
# 80                         NaN                               NaN
# 218                        NaN                               NaN
#
#     Jean Hersholt Humanitarian Award Live Action Short Film Makeup  \
# 692                              NaN                    NaN    NaN
# 417                              NaN                    NaN    NaN
# 183                              NaN                    NaN    NaN
# 392                              NaN                    NaN    NaN
# 476                              NaN                    NaN    NaN
# 495                              NaN                    NaN    NaN
# 714                              NaN                    NaN    NaN
# 854                              NaN                    NaN    NaN
# 80                               NaN                    NaN    NaN
# 218                              NaN                    NaN    NaN
#
#     Makeup and Hairstyling Music (Original Score) Music (Original Song)  \
# 692                    NaN              Nominated                   NaN
# 417                    NaN                    NaN                   NaN
# 183                    NaN                    NaN                   NaN
# 392                    NaN                 Winner                   NaN
# 476                    NaN                    NaN                   NaN
# 495                    NaN                    NaN                   NaN
# 714                    NaN                    NaN                   NaN
# 854                    NaN                    NaN                   NaN
# 80                     NaN                    NaN                   NaN
# 218                    NaN                    NaN                   NaN
#
#     Production Design Short Film (Animated) Short Film (Live Action)  \
# 692         Nominated                   NaN                      NaN
# 417               NaN                   NaN                      NaN
# 183               NaN                   NaN                      NaN
# 392         Nominated                   NaN                      NaN
# 476               NaN                   NaN                      NaN
# 495               NaN                   NaN                      NaN
# 714               NaN                   NaN                      NaN
# 854               NaN                   NaN                      NaN
# 80                NaN                   NaN                Nominated
# 218               NaN                   NaN                      NaN
#
#          Sound Sound Editing Sound Mixing Visual Effects  \
# 692        NaN           NaN          NaN            NaN
# 417        NaN           NaN          NaN            NaN
# 183        NaN           NaN          NaN            NaN
# 392        NaN     Nominated    Nominated         Winner
# 476  Nominated           NaN          NaN      Nominated
# 495        NaN           NaN          NaN            NaN
# 714        NaN           NaN          NaN            NaN
# 854        NaN           NaN          NaN            NaN
# 80         NaN           NaN          NaN            NaN
# 218        NaN           NaN          NaN            NaN
#
#     Writing (Adapted Screenplay) Writing (Original Screenplay)
# 692                       Winner                           NaN
# 417                          NaN                        Winner
# 183                          NaN                           NaN
# 392                    Nominated                           NaN
# 476                          NaN                           NaN
# 495                          NaN                           NaN
# 714                          NaN                           NaN
# 854                          NaN                           NaN
# 80                           NaN                           NaN
# 218                          NaN                           NaN

# %% [markdown]
# ## Outliers Correction

# %%
# IMPURITY #13: The movie titles have some outliers that need to be replaced with the propper movie title
outliers = {
    'Demián Bichir': 'A Better Life',
    'Dimanche/Sunday': 'Dimanche/Sunday (Sunday)',
    'La Maison en Petits Cubes': 'La Maison en Petits Cubes (The House of Small Cubes)',
    'Lavatory - Lovestory': 'Lavatory - Lovestory (Ubornaya istoriya - lyubovnaya istoriya)',
    'Les Mis_rables': 'Les Misérables',
    'Maggie Simpson in "The Longest Daycare"': 'Maggie Simpson in "The Longest Daycare" (The Longest Daycare)',
    'Manon on the Asphalt': 'Manon on the Asphalt (Manon sur le bitume)',
    "Marvel's The Avengers": "Marvel's The Avengers (The Avengers)",
    'Pit__k_ Mun Kaikki Hoitaa? (Do I Have to Take Care of Everything?)': 'Pitääkö mun kaikki hoitaa? (Do I Have to Take Care of Everything?)',
    'Rabbit à la Berlin': 'Rabbit à la Berlin (Królik po berlinsku)',
    "We Can’t Live without Cosmos" : "We Can't Live without Cosmos (Мы не можем жить без космоса)",
    "Bestia" : "Bestia (Beast)",
    "No Time To Die" : "No Time to Die"
}

df_awards["Movie Title"] = df_awards["Movie Title"].replace(outliers)

# %% [markdown]
# ## Enrichment

# %% [markdown]
# ### Enrichment One: Won Oscar Boolean
#
# Add a column that specifies if a movies won any oscar or none at all

# %%
# Add winners, add to initial data though
def check_winner(row):
    categories = df_awards.drop(columns=["Movie Title", "Oscar Ceremony Year", "Cast Involved"]).columns
    for category in categories:
        if row.get(category) == 'Winner':
            return True
    return False

df_awards['Won_Oscars'] = df_awards.apply(check_winner, axis=1)

# %%
df_awards.sample(2)
# Out:
#                                   Movie Title Oscar Ceremony Year  \
# 675                  The Grand Budapest Hotel                2015
# 214  Everything Will Be Okay (Alles Wird Gut)                2016
#
#                                          Cast Involved  \
# 675  Robert Yeoman, Milena Canonero, Wes Anderson, ...
# 214                                   Patrick Vollrath
#
#     Actor in a Leading Role Actor in a Supporting Role  \
# 675                     NaN                        NaN
# 214                     NaN                        NaN
#
#     Actress in a Leading Role Actress in a Supporting Role  \
# 675                       NaN                          NaN
# 214                       NaN                          NaN
#
#     Animated Feature Film Animated Short Film Art Direction Best Picture  \
# 675                   NaN                 NaN           NaN    Nominated
# 214                   NaN                 NaN           NaN          NaN
#
#     Cinematography Costume Design  Directing Documentary (Feature)  \
# 675      Nominated         Winner  Nominated                   NaN
# 214            NaN            NaN        NaN                   NaN
#
#     Documentary (Short Subject) Documentary Feature Film  \
# 675                         NaN                      NaN
# 214                         NaN                      NaN
#
#     Documentary Short Film Film Editing Foreign Language Film  \
# 675                    NaN    Nominated                   NaN
# 214                    NaN          NaN                   NaN
#
#     International Feature Film Irving G. Thalberg Memorial Award  \
# 675                        NaN                               NaN
# 214                        NaN                               NaN
#
#     Jean Hersholt Humanitarian Award Live Action Short Film Makeup  \
# 675                              NaN                    NaN    NaN
# 214                              NaN                    NaN    NaN
#
#     Makeup and Hairstyling Music (Original Score) Music (Original Song)  \
# 675                 Winner                 Winner                   NaN
# 214                    NaN                    NaN                   NaN
#
#     Production Design Short Film (Animated) Short Film (Live Action) Sound  \
# 675            Winner                   NaN                      NaN   NaN
# 214               NaN                   NaN                Nominated   NaN
#
#     Sound Editing Sound Mixing Visual Effects Writing (Adapted Screenplay)  \
# 675           NaN          NaN            NaN                          NaN
# 214           NaN          NaN            NaN                          NaN
#
#     Writing (Original Screenplay)  Won_Oscars
# 675                     Nominated        True
# 214                           NaN       False

# %% [markdown]
# ### Enrichment 2: Amount of Oscars won
#
# Add a column that counts the amount of oscars won

# %%
def count_oscars_won(row):
    categories = df_awards.drop(columns=["Movie Title", "Oscar Ceremony Year", "Cast Involved"]).columns
    count = 0
    for category in categories:
        if row.get(category) == 'Winner':
            count += 1
    return count

df_awards['Oscars_Won'] = df_awards.apply(count_oscars_won, axis=1)

# %%
df_awards.sample(2)
# Out:
#                                            Movie Title Oscar Ceremony Year  \
# 311  If a Tree Falls: A Story of the Earth Liberati...                2012
# 539                                              Rango                2012
#
#                       Cast Involved Actor in a Leading Role  \
# 311  Marshall Curry and Sam Cullman                     NaN
# 539                  Gore Verbinski                     NaN
#
#     Actor in a Supporting Role Actress in a Leading Role  \
# 311                        NaN                       NaN
# 539                        NaN                       NaN
#
#     Actress in a Supporting Role Animated Feature Film Animated Short Film  \
# 311                          NaN                   NaN                 NaN
# 539                          NaN                Winner                 NaN
#
#     Art Direction Best Picture Cinematography Costume Design Directing  \
# 311           NaN          NaN            NaN            NaN       NaN
# 539           NaN          NaN            NaN            NaN       NaN
#
#     Documentary (Feature) Documentary (Short Subject)  \
# 311             Nominated                         NaN
# 539                   NaN                         NaN
#
#     Documentary Feature Film Documentary Short Film Film Editing  \
# 311                      NaN                    NaN          NaN
# 539                      NaN                    NaN          NaN
#
#     Foreign Language Film International Feature Film  \
# 311                   NaN                        NaN
# 539                   NaN                        NaN
#
#     Irving G. Thalberg Memorial Award Jean Hersholt Humanitarian Award  \
# 311                               NaN                              NaN
# 539                               NaN                              NaN
#
#     Live Action Short Film Makeup Makeup and Hairstyling  \
# 311                    NaN    NaN                    NaN
# 539                    NaN    NaN                    NaN
#
#     Music (Original Score) Music (Original Song) Production Design  \
# 311                    NaN                   NaN               NaN
# 539                    NaN                   NaN               NaN
#
#     Short Film (Animated) Short Film (Live Action) Sound Sound Editing  \
# 311                   NaN                      NaN   NaN           NaN
# 539                   NaN                      NaN   NaN           NaN
#
#     Sound Mixing Visual Effects Writing (Adapted Screenplay)  \
# 311          NaN            NaN                          NaN
# 539          NaN            NaN                          NaN
#
#     Writing (Original Screenplay)  Won_Oscars  Oscars_Won
# 311                           NaN       False           0
# 539                           NaN        True           1

# %% [markdown]
# ### Enrichment 3: Percentage of awards won againts all awards

# %%
total_oscars_by_year = df_awards.groupby('Oscar Ceremony Year')['Oscars_Won'].sum().reset_index()
total_oscars_by_year.rename(columns={'Oscars_Won': 'Total_Oscars_Awarded'}, inplace=True)

df_awards = pd.merge(df_awards, total_oscars_by_year, on='Oscar Ceremony Year', how='left')

df_awards['Percentage of Wins'] = round((df_awards['Oscars_Won'] / df_awards['Total_Oscars_Awarded']) * 100, 2)

# %%
df_awards.sample(5)
# Out:
#                   Movie Title Oscar Ceremony Year  \
# 376              Land of Mine                2017
# 409  Ma Rainey's Black Bottom                2021
# 574             Silent Nights                2017
# 494               Our Uniform                2024
# 102             Black Panther                2019
#
#                                          Cast Involved  \
# 376                                            Denmark
# 409  Chadwick Boseman, Viola Davis, Ann Roth, Sergi...
# 574                        Aske Bang and Kim Magnusson
# 494                                   Yegane Moghaddam
# 102  Ruth Carter, Ludwig Goransson, Kevin Feige, Pr...
#
#     Actor in a Leading Role Actor in a Supporting Role  \
# 376                     NaN                        NaN
# 409               Nominated                        NaN
# 574                     NaN                        NaN
# 494                     NaN                        NaN
# 102                     NaN                        NaN
#
#     Actress in a Leading Role Actress in a Supporting Role  \
# 376                       NaN                          NaN
# 409                 Nominated                          NaN
# 574                       NaN                          NaN
# 494                       NaN                          NaN
# 102                       NaN                          NaN
#
#     Animated Feature Film Animated Short Film Art Direction Best Picture  \
# 376                   NaN                 NaN           NaN          NaN
# 409                   NaN                 NaN           NaN          NaN
# 574                   NaN                 NaN           NaN          NaN
# 494                   NaN           Nominated           NaN          NaN
# 102                   NaN                 NaN           NaN    Nominated
#
#     Cinematography Costume Design Directing Documentary (Feature)  \
# 376            NaN            NaN       NaN                   NaN
# 409            NaN         Winner       NaN                   NaN
# 574            NaN            NaN       NaN                   NaN
# 494            NaN            NaN       NaN                   NaN
# 102            NaN         Winner       NaN                   NaN
#
#     Documentary (Short Subject) Documentary Feature Film  \
# 376                         NaN                      NaN
# 409                         NaN                      NaN
# 574                         NaN                      NaN
# 494                         NaN                      NaN
# 102                         NaN                      NaN
#
#     Documentary Short Film Film Editing Foreign Language Film  \
# 376                    NaN          NaN             Nominated
# 409                    NaN          NaN                   NaN
# 574                    NaN          NaN                   NaN
# 494                    NaN          NaN                   NaN
# 102                    NaN          NaN                   NaN
#
#     International Feature Film Irving G. Thalberg Memorial Award  \
# 376                        NaN                               NaN
# 409                        NaN                               NaN
# 574                        NaN                               NaN
# 494                        NaN                               NaN
# 102                        NaN                               NaN
#
#     Jean Hersholt Humanitarian Award Live Action Short Film Makeup  \
# 376                              NaN                    NaN    NaN
# 409                              NaN                    NaN    NaN
# 574                              NaN                    NaN    NaN
# 494                              NaN                    NaN    NaN
# 102                              NaN                    NaN    NaN
#
#     Makeup and Hairstyling Music (Original Score) Music (Original Song)  \
# 376                    NaN                    NaN                   NaN
# 409                 Winner                    NaN                   NaN
# 574                    NaN                    NaN                   NaN
# 494                    NaN                    NaN                   NaN
# 102                    NaN                 Winner                   NaN
#
#     Production Design Short Film (Animated) Short Film (Live Action) Sound  \
# 376               NaN                   NaN                      NaN   NaN
# 409         Nominated                   NaN                      NaN   NaN
# 574               NaN                   NaN                Nominated   NaN
# 494               NaN                   NaN                      NaN   NaN
# 102            Winner                   NaN                      NaN   NaN
#
#     Sound Editing Sound Mixing Visual Effects Writing (Adapted Screenplay)  \
# 376           NaN          NaN            NaN                          NaN
# 409           NaN          NaN            NaN                          NaN
# 574           NaN          NaN            NaN                          NaN
# 494           NaN          NaN            NaN                          NaN
# 102     Nominated    Nominated            NaN                          NaN
#
#     Writing (Original Screenplay)  Won_Oscars  Oscars_Won  \
# 376                           NaN       False           0
# 409                           NaN        True           2
# 574                           NaN       False           0
# 494                           NaN       False           0
# 102                           NaN        True           3
#
#      Total_Oscars_Awarded  Percentage of Wins
# 376                    23                0.00
# 409                    21                9.52
# 574                    23                0.00
# 494                    22                0.00
# 102                    23               13.04

# %% [markdown]
# ## Save Data

# %%
df_awards.to_csv("../Data/Bacher_Dominik_studentA_stage3.csv", index=False)

# %%
df_awards.columns
# Out:
# Index(['Movie Title', 'Oscar Ceremony Year', 'Cast Involved',
#        'Actor in a Leading Role', 'Actor in a Supporting Role',
#        'Actress in a Leading Role', 'Actress in a Supporting Role',
#        'Animated Feature Film', 'Animated Short Film', 'Art Direction',
#        'Best Picture', 'Cinematography', 'Costume Design', 'Directing',
#        'Documentary (Feature)', 'Documentary (Short Subject)',
#        'Documentary Feature Film', 'Documentary Short Film', 'Film Editing',
#        'Foreign Language Film', 'International Feature Film',
#        'Irving G. Thalberg Memorial Award', 'Jean Hersholt Humanitarian Award',
#        'Live Action Short Film', 'Makeup', 'Makeup and Hairstyling',
#        'Music (Original Score)', 'Music (Original Song)', 'Production Design',
#        'Short Film (Animated)', 'Short Film (Live Action)', 'Sound',
#        'Sound Editing', 'Sound Mixing', 'Visual Effects',
#        'Writing (Adapted Screenplay)', 'Writing (Original Screenplay)',
#        'Won_Oscars', 'Oscars_Won', 'Total_Oscars_Awarded',
#        'Percentage of Wins'],
#       dtype='object')
